# %% [markdown]
# ## Requirement Setup
# In this section the requirements for running the notebook are leveraged

# %%
#!nvidia-smi

# %%
#!pip install tensorflow-gpu==2.0

# %%
import tensorflow as tf
import numpy as np

import json

import os
#To free memory
import gc

# %%
print(tf.__version__)
print(tf.config.experimental.list_physical_devices())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

#tf.debugging.set_log_device_placement(True)
# Out:
# 2.0.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:XLA_CPU:0', device_type='XLA_CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:XLA_GPU:0', device_type='XLA_GPU')]
# Num GPUs Available:  1

# %% [markdown]
# ## Data manipulation
# ### Data Obtention

# %%
if not "annotations" in os.listdir():
    if not "annotations_trainval2014.zip" in os.listdir():
        # !wget "http://images.cocodataset.org/annotations/annotations_trainval2014.zip"
    # !unzip annotations_trainval2014.zip

# %%
if not "val2014" in os.listdir():
    if not "val2014.zip" in os.listdir():
        # !wget "http://images.cocodataset.org/zips/val2014.zip"
    # !unzip val2014.zip

# %%
def load_annotation_data(annotation_filename):
    annotations_file = open(annotation_filename)
    annotations_js = json.load(annotations_file)
    
    annotation_list = [(j["image_id"],j["caption"]) for j in annotations_js["annotations"]]
    annotation_list.sort()

    data = [{"id" : annotation_list[0][0] , "captions" : [annotation_list[0][1]]}]

    for img_id , capt in annotation_list[1:]:

        if data[-1]["id"] != img_id:
            data.append({"id" : img_id , "captions" : []})

        data[-1]["captions"].append(capt)

    return data

# %%
annotations_data_train = load_annotation_data("annotations/captions_train2014.json")
annotations_data_val = load_annotation_data("annotations/captions_val2014.json")

# %%
print("Data as of the files:")
print()

print("Image count train: ",len(annotations_data_train))
print("Image count val: ",len(annotations_data_val))
# Out:
# Data as of the files:
#
# Image count train:  82783
# Image count val:  40504

# %%
val_size = 5000
test_size = 10000

annotations_data_test = annotations_data_val[:test_size]
annotations_data_val = annotations_data_val[test_size:]
annotations_data_train += annotations_data_val[val_size:]
annotations_data_val = annotations_data_val[:val_size]

# %%
print("Redistributed data:")
print()

print("Image count train: ",len(annotations_data_train))
print("Image count val: ",len(annotations_data_val))
print("Image count test: ",len(annotations_data_test))
# Out:
# Redistributed data:
#
# Image count train:  108287
# Image count val:  5000
# Image count test:  10000

# %%
annotations_data_train
# Out:
# [{'id': 9,
#   'captions': ['A bunch of trays that have different food.',
#    'A meal is presented in brightly colored plastic trays.',
#    'Closeup of bins of food that include broccoli and bread.',
#    'Colorful dishes holding meat, vegetables, fruit, and bread.',
#    'there are containers filled with different kinds of foods']},
#  {'id': 25,
#   'captions': ['A giraffe eating food from the top of the tree.',
#    'A giraffe mother with its baby in the forest.',
#    'A giraffe standing next to a forest filled with trees.',
#    'A giraffe standing up nearby a tree ',
#    'Two giraffes standing in a tree filled area.']},
#  {'id': 30,
#   'captions': ['A flower vase is sitting on a porch stand.',
#    'A vase with red and white flowers outside on a sunny day.',
#    'A white vase filled with different colored flowers.',
#    'White vase with different colored flowers sitting inside of it. ',
#    'a white vase with many flowers on a stage']},
#  {'id': 34,
#   'captions': ['A lone zebra grazing in some green grass.',
#    'A zebra grazing on lush green grass in a field.',
#    'The zebra is eating grass in the sun.',
#    'Zebra reaching its head down to ground where grass is. ',
#    'a Zebra grazing on grass in a green open field.']},
#  {'id': 36,
#   'captions': ['A girl in a bathing suit with a pink umbrella.',
#    'A woman in a floral swimsuit holds a pink umbrella.',
#    'A woman posing for the camera, holding a pink, open umbrella and wearing a bright, floral, ruched bathing suit, by a life guard stand with lake, green trees, and a blue sky with a few clouds behind.',
#    'A woman with an umbrella near the sea',
#    'Woman in swim suit holding parasol on sunny day.']},
#  {'id': 49,
#   'captions': ['A couple of men riding horses on top of a green field.',
#    'A pair of horses performing tricks in a field. ',
#    'Two costumed horse riders make their horses stand on their hind legs.',
#    'Two men are on horses that are reared back.',
#    'two horses and their riders on some grass']},
#  {'id': 61,
#   'captions': ['SOME PEOPLE IN THE WOODS RIDING TWO ELEPHANTS',
#    'Several elephants in the jungle carrying people on their backs',
#    'Some people who are riding on top of elephants.',
#    'They are brave for riding in the jungle on those elephants.',
#    'there are people riding elephants in the middle of a forest']},
#  {'id': 64,
#   'captions': ['A clock is seen in front of a tall tree.',
#    'A clock sits on top of a black pole near a tree on a sidewalk near a crosswalk.',
#    'A pole with a clock that reads 6:10 by a white car. ',
#    'A very pretty clock on the side of a road.',
#    'a black and silver clock tower at an intersection near a tree']},
#  {'id': 71,
#   'captions': ['A passenger train glides around a curve on the outer track.',
#    'A train coming down the tracks in the city.',
#    'A train coming to a stop on the tracks out side.',
#    'A train engine carrying many carts down a track.',
#    'The very long train is travelling down the tracks.']},
#  {'id': 72,
#   'captions': ['A couple of giraffe snuggling each other in a forest.',
#    'A couple of giraffe standing next to some trees.',
#    'The two giraffes appear to be hugging each other.',
#    'Two Zebras seem to be embracing in the wild. ',
#    'Two giraffes hang out near trees and nuzzle up to each other.']},
#  {'id': 77,
#   'captions': ['A time lapse image of a guy on a skate board.',
#    'A young man riding a skateboard into the air.',
#    'Group of boys performing skateboard trick on ramp with graffiti on it',
#    'a group of teenagers jumping a ramp on their skateboards',
#    'some male skateboarders are doing some tricks and grafitti']},
#  {'id': 78,
#   'captions': ['A lighted owl candle sits next to a clock.',
#    'An antique looking clock beside an owl with a candle in it.',
#    'An owl candle and a clock sitting in front of a wall.',
#    'White clock sitting next to a statue of an owl. ',
#    'a close up of a clock near an owl candle holder ']},
#  {'id': 81,
#   'captions': ['A big airplane flying in the big blue sky',
#    'A big plane with AirFrance on the side of it.',
#    'An Air France air plane in mid flight.',
#    'An AirFrance jet airplane flying in the sky ',
#    'Large, two decked, four engined airliner in flight.']},
#  {'id': 86,
#   'captions': ['A man on a an old fashioned bicycle in the woods ',
#    'A man riding a motor bike across a forest.',
#    'A man sitting on a motorcycle in the woods.',
#    'A person looks down at something while sitting on a bike. ',
#    'A young person is on a very ornate old bicycle.']},
#  {'id': 89,
#   'captions': ['A small light is on above the polished stove top.',
#    'A stove top is cleaned with a set of knives on the wall.',
#    'A stove with a lighted hood in the kitchen.',
#    'An oven with a stove on top of it in a kitchen.',
#    'Smooth top stove with exhaust fan that has light turned on.']},
#  {'id': 92,
#   'captions': ['A chocolate desert on a plate with a fork. ',
#    'A piece of chocolate cake on top of a white plate.',
#    'A piece of chocolate dessert on a plate with a napkin and a fork.',
#    'A white plate with a brownie and white frosting.',
#    'a chocolate cake and a fork ready to be eat']},
#  {'id': 94,
#   'captions': ['A city street with a sign that reads "Peace Way Hotel".',
#    'A street sign and a car on the road.',
#    'There is a car driving down a street with buildings on each side.',
#    'There is a street lined with packed buildings',
#    'This is a view of a quaint city street.']},
#  {'id': 109,
#   'captions': ['A skate park next to a body of water and green park.',
#    'A waterfront walkway and garden area next to a river.',
#    'A wide walkway allows for walks along the river.',
#    'Sky view of a walkway along the shore of a river.',
#    'some grass and a person in a blue shirt walking a dog and water']},
#  {'id': 110,
#   'captions': ['A lady and a child are sitting.The lady is cutting pizza pieces.',
#    'A woman and child sitting at a table with a pizza in front of them.',
#    'A woman cutting a pizza with a fork and knife ',
#    'A woman cutting a pizza with a fork and knife.',
#    'Woman cutting pizza with fork and knife sitting next to young girl']},
#  {'id': 113,
#   'captions': ['A man and woman standing in front of a cake.',
#    'A woman cutting into a cake with a man standing behind her',
#    'A women who is cutting into a cake.',
#    'a man and woman cut into a big cake ',
#    'two people standing near a table with a cake ']},
#  {'id': 127,
#   'captions': ['A dessert and a cup of coffee sit next to a book and a purse.',
#    'A piece of cake and coffee are on an outdoor table.',
#    'A slice of cake and mug sitting on a wooden table outside.',
#    'Slice of cake next to large filled cup on wooden table.',
#    'a close up of a slice of cake on a plate']},
#  {'id': 138,
#   'captions': ['A series of photographs of a tiny model kitchen',
#    'Collage of pictures from a clean rustic kitchen. ',
#    'Picture of a kitchen this has smaller photos of item within that kitchen. ',
#    'The kitchen has odd looking colors in it.',
#    'Three dimensional rendering of a kitchen area with various appliances. ']},
#  {'id': 142,
#   'captions': ['A sliced banana topped dessert sits on a plate.',
#    'Plate with a piece of bread, dark chocolate spread, bananas and a carton of Silk.',
#    'There is a plate of banana and chocolate on bread',
#    'a close up of a plate of a jelly and banana sandwich',
#    'bread with banana milk and nutella on a table']},
#  {'id': 144,
#   'captions': ['Three giraffes standing in the dirt in a fenced in area.',
#    'Three giraffes stuck behind the confines of a zoo fence. ',
#    'Two giraffes eating together out of a trough in a fenced area.',
#    'a couple of giraffes eat some food out of a trey ',
#    'a number of giraffes near one another ']},
#  {'id': 149,
#   'captions': ['A host of kites being flown on a field by people.',
#    'People are flying kites on a high school field.',
#    'People flying kites in a field on a cloudy day.',
#    'People gathered outside in a big field on a cloudy day',
#    'a bunch of people are at a grass field ']},
#  {'id': 151,
#   'captions': ['A man leans out of a vehicle near a short stop sign in a forest.',
#    'A stop sign directs pedestrians as a train travels by.',
#    'A stop sign is shown close to the ground.',
#    'A stop sign sits in the middle of the forest. ',
#    'A stop sign sitting near some tall trees.']},
#  {'id': 154,
#   'captions': ['Three zebra are walking through the grass of a field.',
#    'Three zebras are standing in an open field.',
#    'Three zebras grazing in green grass field area.',
#    'Three zebras standing on a grassy dirt field.',
#    'three zeebras standing in a grassy field walking']},
#  {'id': 165,
#   'captions': ['A funny picture of a woman holding a large pair of scissors attempting to cut a mans tie.',
#    'A man in a suit and a woman in military clothes.',
#    "A woman in a soldier's uniform pretends to cut the tie of a man using an enormous pair of scissors.",
#    "A woman soldier holding up a pair of giant scissors to someone's tie.",
#    "a female in military uniform cutting a businessman's neck tie"]},
#  {'id': 194,
#   'captions': ['A small personal sized pizza is shown on display.',
#    'An exotic pizza sits on a plate, with cheese and bits of meat on top.',
#    'Small pizza sitting on a white plate with different toppings on it. ',
#    'The pizza is loaded with lots of toppings.',
#    'a small pizza that is on a white plate']},
#  {'id': 201,
#   'captions': ['A row of snow boards sticking out of the snow.',
#    'Five skateboards on a rack in a snow covered mountain ',
#    'Six snowboards are propped in the snow on a rail.',
#    'Snowboards sticking in the snow by a rack ',
#    'There are skateboards leaning on a metal bar.']},
#  {'id': 247,
#   'captions': ['A red, white and blue helicopter has a tag on one blade.',
#    'A small engine plane sitting on an air field being displayed.',
#    'A small plane with a certificate on the propellers.',
#    'a plane sits on a runway waiting for lift off',
#    'a small airplane that is on a runway']},
#  {'id': 250,
#   'captions': ['A Greenwich street and Vesey street sign are hanging on a pole.',
#    'A city street has an intersection sign on a pole.',
#    'A street sign on a pole on a street.',
#    'Street signs near tall buildings on the corner of Greenwich St and Vesey St.',
#    'Two green and white street signs with building in background.']},
#  {'id': 260,
#   'captions': ['A female traveler leaning on a luggage cart.',
#    'A woman is waiting with a cart full of luggage.',
#    'A woman next to a cart of luggage at a bus stop.',
#    'A woman wearing a yellow shirt standing next to luggage.',
#    'the woman is standing with her luggage ']},
#  {'id': 263,
#   'captions': ['A baby elephant tries to get on top of another elephant. ',
#    'A couple of elephants playing with each other in their pen.',
#    'A couple of elephants standing next to each other.',
#    'Adult elephant pushing a baby elephant with its leg.',
#    'One adult and one small elephant in a dry lot.']},
#  {'id': 307,
#   'captions': ['A brown and white dog chasing a blue and yellow frisbee.',
#    'A collie chasing a frisbee in the grass.',
#    'A cute dog is in the grass with a frisbee.',
#    'A dog that is standing in the grass near a frisbee.',
#    'The dog is playing with his toy in the grass']},
#  {'id': 308,
#   'captions': ['A man pouring wine from casks for patrons',
#    'Group of people tasting wine next to some barrels.',
#    'People are gathered around a man tasting wine.',
#    'People gather around a table while sampling wine.',
#    'the people are sampling wine at a wine tasting.']},
#  {'id': 309,
#   'captions': ['A dog stands in the grass next to a stuffed bear.',
#    'A small brown stuffed bear laying in the grass.',
#    'A stuffed bear that is laying down in the grass.',
#    'A teddy bear is laying on the green grass next to a dog. ',
#    'A teddy bear lays on the lawn and a dog stands behind it.']},
#  {'id': 312,
#   'captions': ['A baby elephant walks through the forest with five adult elephants.',
#    'A herd of elephants one running with a baby.',
#    'A herd of elephants, including a tiny baby elephant, cross a dirt road.',
#    'A large group of elephants crossing a dirt path.',
#    'Four large elephants are watching over their baby in the wilderness.']},
#  {'id': 315,
#   'captions': ['Beautiful women wearing bikinis frolicking on a sandy beach.',
#    'Groups of people sit on a beach in the sand.',
#    'People sunbathing and sitting under umbrellas at a city beach.',
#    'Women are walking towards seats on the beach.',
#    'people in bikinis at a beach under umbrellas']},
#  {'id': 321,
#   'captions': ['A sub sandwich in a box next to two hot dogs.',
#    'The takeout containers hold two hot dogs with condiments, and a steak sandwich.',
#    'Two styrofoam carryout containers, one with a steak sub with jalapeno peppers, and the other with two hot dogs.',
#    'a close up of a plastic container with hot dogs',
#    'two plastic containers holding onto a sandwich and hot dogs ']},
#  {'id': 322,
#   'captions': ['A full view of a man throwing a Frisbee.',
#    'A man tossing an orange frisbee on top of a lush green field.',
#    'A person is throwing a Frisbee at night. ',
#    'Man playing with flying red disk outdoors in evening.',
#    'a man standing in a yard with a red frisbee']},
#  {'id': 326,
#   'captions': ["A man holding a glass of wine on it's side.",
#    'A man tilting a glass of wine.to the side.',
#    'A man tips a clear wine glass to observe its makeup. ',
#    'A person holding a partially filled wine glass.',
#    'a male in a white shirt is holding a glass of wine']},
#  {'id': 332,
#   'captions': ['A bowl of pasta, carrots, egg roll and cabbage.',
#    'A plate of food: meat, noodles, sprouts, carrots and salad',
#    'Asian noodles, cut up egg roll with greens and carrots in a white bowl.',
#    'Food in a bowl with carrots and drinks around it',
#    'Healthy foods being used to create a dinner dish.']},
#  {'id': 349,
#   'captions': ['A lone train sits on the train track under the bridge.',
#    'A trailer is sitting under a bridge and some power lines.',
#    'A white and orange train passing by trees and a lamppost.',
#    'An old train drives on the tracks under a bridge. ',
#    'The passenger train has stopped at a station.']},
#  {'id': 368,
#   'captions': ['A group of kids playing soccer on a field.',
#    'A young boy playing soccer on a grassy field',
#    'A young man kicking a soccer ball around a field.',
#    'Small child in soccer uniform kicking at yellow ball. ',
#    'There are several young boys practicing soccer, some with their dads.']},
#  {'id': 370,
#   'captions': ['A little girl holding wet broccoli in her hand. ',
#    'A little girl holds a hand full of wet broccoli. ',
#    'A little girl holds a piece of broccoli towards the camera.',
#    'The young child is happily holding a fresh vegetable. ',
#    'a small kid holds on to some vegetables ']},
#  {'id': 382,
#   'captions': ['A distance shot shows rolling snowy hills, partially shadowed, with ski prints reaching off into the distance, and to the foreground, a single skier. ',
#    'A high mountain of snow with a cross country skier.',
#    'A man riding skis down a snow covered slope.',
#    'A mountain slope photo with a person on skis in the foreground.',
#    'landscape of a snowy mountain with a skiers trail in the snow']},
#  {'id': 384,
#   'captions': ['A living room filled with furniture and windows covered in curtain.',
#    'A living room with a couch, coffee table and two large windows with white curtains.',
#    'A living room with a couch, coffee table and two windows.',
#    'This is a living room with white curtains.',
#    'a living room with white curtains and a black couch and table']},
#  {'id': 389,
#   'captions': ['A man with a bushy beard and green tie.',
#    'A man with a long grey beard in a white shirt and green tie at a pub full of green-shirted patrons.',
#    'A woman standing in a large group of people near stairs.',
#    'The man smiles wearing a green neck tie near a crowd of people. ',
#    'This man is very happy to be at the gathering.']},
#  {'id': 394,
#   'captions': ["A white dog has a purple Frisbee in it's mouth.",
#    "A white dog holding a purple frisbee in it's mouth.",
#    'A white dog is holding a frisbee in its mouth waiting to play.',
#    'White dog carrying a purple frisbee on a lawn.',
#    'a dog is holding a frisbee standing on grass']},
#  {'id': 404,
#   'captions': ['A pair of boats docked at a pier is shown.',
#    'Three boats are docked together on the cloudy day.',
#    'Three boats docked in still water with clouds in the sky. ',
#    'a couple of boats that are in some water',
#    'some colorful boats sitting next to a dock ']},
#  {'id': 419,
#   'captions': ['A tennis player taking  a swing at  a ball',
#    'Two people at a public tennis court; one serves the ball.',
#    'Two people on the tennis court playing tennis',
#    'Two people playing tennis in a neighborhood park. ',
#    'two people playing tennis on a tennis court.']},
#  {'id': 431,
#   'captions': ['A male tennis player hits the ball on a grass court.',
#    'A man in motion hitting a tennis ball with a tennis racket on a tennis court.',
#    'A tennis player in action on the court.',
#    'a male in a white shirt is playing tennis',
#    'a man that is playing tennis on a court']},
#  {'id': 436,
#   'captions': ['A man is eating a roll and licking his thumb.',
#    'A man licking his thumb with a peanut buttered bread slice in his hand.',
#    'A person licks his thumb while holding a piece of food.',
#    'Man wearing glasses eating a slice of food.',
#    'there is a person sitting and licking their fingers']},
#  {'id': 438,
#   'captions': ['A big box of various types of doughnuts.',
#    'A box full of donuts in different shapes and flavors.',
#    'A box of chocolate, filled, sour cream donuts.',
#    'A variety of donuts and pastries in a box.',
#    'Various pastries are displayed in a take out box.']},
#  {'id': 443,
#   'captions': ["A cat is lying on its back in a man's lap.",
#    'A cat laying on a persons lap who is sitting on a couch',
#    "A cat lays on its back while sitting in someone's lap.",
#    "A cat sits with his belly up in a person's lap.",
#    'A person sitting on a couch with a cat laying on its back.']},
#  {'id': 446,
#   'captions': ['A woman holding a remote control in her right hand.',
#    'A woman playing a video game indoors. ',
#    'A woman standing in a room holding a remote control.',
#    'A woman stands with a Wii remote in her hand.',
#    'a standing woman with a remote control in hand ']},
#  {'id': 450,
#   'captions': ['A fresh cheese and basil pizza on a white plate',
#    'A pizza sitting on a white plate next to a glass of water.',
#    'A pizza with basil leaves served on a plate',
#    'A small pizza with sits on a white plate.',
#    'a margherita pizza being served on a plate']},
#  {'id': 471,
#   'captions': ['A Los Angeles school bus parked in a parking lot.',
#    'A yellow bus is shown parked in a parking lot.',
#    'A yellow bus without passengers standing on the road.',
#    'An old yellow school bus is parked in a lot.',
#    'a yellow school bus parked in a parking lot']},
#  {'id': 490,
#   'captions': ['A dog is looking at someone in the room.',
#    'A dog standing next to a skateboard on a wall.',
#    'A dog standing on hard wood floors and next to a wall with his shadow.',
#    'A dog stands next to a skateboard leaned up against a wall.',
#    'Dog and skateboard in a room and shadow of dog and person on a wall.']},
#  {'id': 491,
#   'captions': ['A number of stuffed toy dogs set together.',
#    'Stuffed animals are hanging on poles in the air.',
#    'This  bear is a soft, furry prize children want to win a the summer carnival.',
#    'Toy Pomeranian dog on bag for playing with and enjoyment.',
#    'a white stuffed bear is in a room']},
#  {'id': 508,
#   'captions': ['A field covered in snow on top of a hillside.',
#    'A scenic view of a snow covered mountain and clouds.',
#    'A sign stands on a snowy kill under a cloudy sky.',
#    'Snow that is on a hill overlooking mountains.',
#    'Sun peeks through the cloudy on top of a snowy mountain.']},
#  {'id': 510,
#   'captions': ['A man holding his hands together while sitting on a bench.',
#    'A man sits on a bench with a man-made waterfall behind him. ',
#    'A man sitting on top of a brown bench in front of a fountain.',
#    'An old man sits on a park bench beside a fountain',
#    'Older man sitting on bench in front of water fountain']},
#  {'id': 514,
#   'captions': ['A bed is covered by a gold decorative cover. ',
#    'A very big and fancy looking room with a big pretty bed.',
#    'Old style bed has a cross on the headboard',
#    'This is bed in someones bedroom in their house. ',
#    'a bed room that is filled with ancient cloth like sheets ']},
#  {'id': 529,
#   'captions': ['A guy and a girl hugging on a dirt bike. ',
#    'A man riding a motorcycle with a beautiful woman on his lap.',
#    'A motorcyclist and a woman posing on a bike for a photo.',
#    'A rider sits on a dirt bike with a woman in his lap.',
#    'Man on dirt bike with a redheaded woman in his lap.']},
#  {'id': 531,
#   'captions': ["A group of people playing double's tennis outdoors",
#    'People playing tennis on the court on a sunny day',
#    'Two tennis courts both have doubles games playing on them.',
#    'Wide shot o group playing tennis on a court.',
#    'a group of people on a tennis court playing tennis ']},
#  {'id': 532,
#   'captions': [' A man and two women disembark from two colorful busses.',
#    'A man standing next to a large red bus.',
#    'A man stands next to a red bus on the street',
#    'Man standing outside a red and black school bus.',
#    'Two people standing outside of a remodeled school bus']},
#  {'id': 540,
#   'captions': ['A JAL airplane taxiing down a runway in a city.',
#    'A large jetliner taking off from an airport runway.',
#    'An airplane on a bridge over a highway.',
#    'An airplane sitting in the middle of a city. ',
#    'Very large JAL jet taxiing on the runway at airport in urban environment']},
#  {'id': 542,
#   'captions': ['A group of people standing around an airplane.',
#    "Men are standing in front of a prop plane and one man is actually standing in the driver's area and holding on to the top wing.",
#    'People gather around as a man gets into an old-time airplane.',
#    'Several people standing around and looking at a vintage plane.',
#    'large group of people standing next to very old style air plane']},
#  {'id': 560,
#   'captions': ['A CGI bathroom with a oval tub filled with water.',
#    'A computer rendering of a bathroom shows stone walls and a large tub with a window.',
#    'The sink of a large modern bathroom is full of water.',
#    'This is a bathroom with a jacuzzi, shower, sink, and toilet.',
#    'a bathroom with a tub a toilet and a stand up shower']},
#  {'id': 562,
#   'captions': ['A glass of toothbrushes sitting on a counter',
#    'Three colored toothbrushes standing in a glass holder.',
#    'Three toothbrushes are in a clear glass cup.',
#    'Three toothbrushes sit inside of a glass on the counter.',
#    'an image of three toothbrushes in side a glass holder']},
#  {'id': 572,
#   'captions': ["A man leaning over as she inspects a woman's shoes.",
#    'Man standing in front of a woman next to a suitcase. ',
#    'a man kneeling down looking at a ladies shoes',
#    'a person standing and a person looking down',
#    'this is two men standing on some stairs']},
#  {'id': 575,
#   'captions': ['A cat is in the grass chewing on a shoestring. ',
#    'A cat playing with a shoe in a grassy field.',
#    'The cat is laying in the grass next to a shoe. ',
#    'a close up of a cat laying on grass near a shoe',
#    'an image of a cat that is playing with a shoe']},
#  {'id': 581,
#   'captions': ['A Chihuahua dog is standing next to a toy giraffe and looking up. ',
#    'A brown and white chihuahua stands over a stuffed giraffe toy and a gray ribbon.',
#    'The chihuahua is looking up at the wooden structure rather than at the moose on the ground.',
#    'The small dog is looking up at the camera.',
#    'there is a white and beige dog sitting on the floor']},
#  {'id': 584,
#   'captions': ['A close up picture of a meal on a white plate.',
#    'A cooked stir fry dish arranged on a plate.',
#    'A picture of a bowl of food that is mostly vegetables.',
#    'Food on a white plate with vegetables and a garnish.',
#    'a plate of yummy food of some kind']},
#  {'id': 595,
#   'captions': ['A television sitting in the middle of a river',
#    'A tv in the middle of a fast flowing river.',
#    'A tv sitting next to a river with a busted screen.',
#    'An old TV monitor sits in the middle of a stream.',
#    'There is an old TV in the middle of a swamp']},
#  {'id': 597,
#   'captions': ['A heard of elephants are walking through the field in a line.',
#    'A herd of elephants and their calves walking single file',
#    'A herd of elephants cross an exotic savanna.',
#    'A herd of elephants walking across a dry grass field.',
#    'Elephant herd, in a line, walking across savanna.']},
#  {'id': 605,
#   'captions': ['A cappuccino cup next to plates of deserts.',
#    'A cup of coffee on a plate with a spoon.',
#    'A cup of liquid with a fancy design on top of it.',
#    'Cup of coffee with dessert items on a wooden grained table.',
#    'Pastry, water and a cup of coffee with spoon.']},
#  {'id': 612,
#   'captions': ['A bunch of stuffed animals laying on a bed.',
#    'A group of teddy bears laying on top of a red bed.',
#    'Large group of stuffed animals sitting on top of a red bed. ',
#    'There is a canopy bed with red sheets, and a bunch of stuffed animal on it. there are two furry lamps on nightstands next to the bed.',
#    'a brightly decorated bedroom with assorted stuffed animals in the room ']},
#  {'id': 620,
#   'captions': ['Large cheese pizzas stacked in a warming oven.',
#    'Pans of dough sit atop racks holding pizzas. ',
#    'Three pans of pizza in a cart that holds pizzas. ',
#    'a couple of pizzas are sitting on racks',
#    'some large pizzas on trays and some orange floor tiles ']},
#  {'id': 625,
#   'captions': ['3 people attempt to catch a frisbee in midair. ',
#    'A group of woman standing in a field trying to catch a frisbee',
#    'Three girls playing frisbee together in a field.',
#    'Three young women are trying to catch a frisbee.',
#    'three people in a grass field reaching for a frisbee in the air']},
#  {'id': 629,
#   'captions': ['A close up of a motorcycle parked on the sidewalk next to a door.',
#    'A motorcycle parked on the side of a building with mural',
#    'An old motorcycle parked outside a rustic building.',
#    "An old motorcycle rests on it's kickstand by a door, in front of a wall with a mural of a tree.",
#    'Rusted red motorcycle parked beside a red building. ']},
#  {'id': 634,
#   'captions': ['A kid on a skate board riding on a ramp.',
#    'A man riding a skateboard on a ramp.',
#    'A person standing on a skateboard and skating at a park.',
#    'A teenager riding a skateboard at a skate park.',
#    'A young man riding a skateboard down a ramp.']},
#  {'id': 643,
#   'captions': ['A computer desk with a desktop computer and a stuffed turtle on top. ',
#    'A computer is on a desk along with several knickknacks.',
#    'A desktop computer and monitor on a  desk.',
#    'A desktop computer with a stuffed animal turtle on top.',
#    'There is a stuffed turtle on the computer monitor. ']},
#  {'id': 650,
#   'captions': ['A cat sitting on top of a car near bushes.',
#    'A curious looking cat sitting on a car.',
#    'Cat sitting on top of car with brush behind. ',
#    'a black gray and white cat a car and bushes',
#    'a cat is sitting on top of a vehicle']},
#  {'id': 656,
#   'captions': ['A gold and black motorcycle is parked by some grass.',
#    'A gold motorcycle parked in parking lot next to a building.',
#    'A motorcycle parked in a parking space in front of a store.',
#    'A motorcycle parked in a parking spot in a lot.',
#    'there is a orange and black motorcycle that is parked ']},
#  {'id': 659,
#   'captions': ['A train engine carrying carts parked at a station.',
#    'A train with googly eyes sitting near a platform.',
#    'Train with bright striped rear with attendants and onlookers on platform.',
#    'a yellow and black stripped train next to sidewalk',
#    'there is a train that is stopped at the station']},
#  {'id': 670,
#   'captions': ['A bunch of boxes full of assorted fruit on display.',
#    'A display of boxes with several types of fruits.',
#    'A fruit and produce stand with food being displayed in produce boxes.  ',
#    'Apples, oranges and other fruit displayed for sale in boxes',
#    'Boxes of fresh fruit on display in a market.']},
#  {'id': 671,
#   'captions': ['A statue of a man on a horse and a group of trees with no leaves behind it. ',
#    'A statue of a man on top of a horse.',
#    'A statue of a roman soldier sitting on a horse.',
#    'A statue of a soldier sitting atop a horse',
#    'Statue of man with cape on horse in front of trees and building.']},
#  {'id': 673,
#   'captions': ['A big empty beach with a bunch of surf boards.',
#    'A sandy beach covered in white surfboards near the ocean.',
#    'Eleven surfboards face down on an empty beach.',
#    'Many surfboards laying in the sand at the beach.',
#    'surfboards sitting on the sand of a beach']},
#  {'id': 681,
#   'captions': ['A large long white bus on a road.',
#    'A red and white bus driving down the side of a road.',
#    'A white and red bus on side of street.',
#    'Passenger bus parked on street with sunset in background',
#    'The bus is parked on the quiet road waiting for its passengers.']},
#  {'id': 684,
#   'captions': ['A three piece circular mirror with a girl taking a picture of it in the reflection',
#    'A woman and a cat reflected in a mirror made of three circular sections',
#    'A woman is taking a picture looking into a mirror while the cat watches.',
#    'A woman that is with a cat in a mirror.',
#    'a woman taking a selfie in front of a stack of mirrors']},
#  {'id': 690,
#   'captions': ['A man on a motorcycle is going down the street.',
#    'A man riding a motorcycle next to a lush green forest.',
#    'A motorcyclist travels down a country two-lane highway.',
#    'A person is riding a motorcycle down a country road.',
#    'a person riding a motorcycle on a road with trees']},
#  {'id': 706,
#   'captions': ['A giraffe standing alone next to a tree.',
#    'A giraffe standing in a stand of trees. ',
#    'A single giraffe stand among some busy trees.',
#    'The giraffe stands alone in very tall brush.',
#    'a giraffe standing in front of a tree ']},
#  {'id': 714,
#   'captions': ['A bathroom is made over and painted and decorated',
#    'A set of two pictures of two toilets in a bathroom.',
#    'Two bathrooms with different decor on each of them',
#    'Two different bathrooms, one has a green toilet',
#    'a split photo with some toilets inside of it ']},
#  {'id': 716,
#   'captions': ['A group of people that are sitting in front of laptops.',
#    'People are sitting in the dark using computers. ',
#    'The extra laptop is on standby for the computer users.',
#    'The people are using their computers in the dark. ',
#    'a dark room with three people on computers']},
#  {'id': 722,
#   'captions': ['Clowns are bowing to each other at an air show.',
#    'Clowns are on hand to assist fliers with their kites.',
#    'People are gathering near bright orange air balloons.',
#    'Some colorful kits being flown on a field during the day.',
#    'a group of people in a field flying large floats ']},
#  {'id': 723,
#   'captions': ['A bar and cafe with a motorcycle parked out front.',
#    'A large motorcycle sits outside of a bar.',
#    'A motorcycle is parked in front of a cafe.',
#    'A motorcycle is parked outside of a cafe.',
#    'a motorcycle parked in front of a small cafe']},
#  {'id': 731,
#   'captions': ['A lady stands in a flooded grassy spot surrounded by tents.',
#    'A woman holding her umbrella is standing in a quite large puddle. ',
#    'A woman under and umbrella standing in water on a flooded field with tents in the background.',
#    'A woman wearing a pink hat holding a black umbrella.',
#    'Female camper standing ankle deep in water under an umbrella']},
#  {'id': 735,
#   'captions': ['A woman cuts a large cake that has a lit candle.',
#    'A woman has her picture taken while she cuts a cake.',
#    'A woman with a knife cutting into a cake.',
#    'A women cutting a large cake with one lit candle.',
#    'a woman cutting into a big birthday cake with one candle']},
#  {'id': 753,
#   'captions': ['A giraffe in a field staring at the camera.',
#    'A giraffe is turning its head to look at the photographer',
#    'A giraffe standing and posing in a prairie setting.',
#    'The giraffe is standing alone in the wilderness.',
#    'a giraffe standing in tall grass with trees in the background']},
#  {'id': 754,
#   'captions': ['A bathroom has a bottle of cleaning wipes.',
#    'A small bathroom with a glass shower door, sink, toilet, and disinfecting wipes.',
#    'A small bathroom with a mirror, shower, toilet and vanity.',
#    'A toilet with sink, sanitizers  and a mirror',
#    'A yellow Clorox wipe dispenser sitting on a bathroom sink.']},
#  {'id': 762,
#   'captions': ['A living room filled with furniture on top of a hard wood floor.',
#    'A very big nice looking room with a bright window.',
#    'Living room with wood floor TV couches and chair.',
#    'a living room filled with couches chairs and a water cooler sitting on a hard wood floor',
#    'a living room with big couches and a ceiling fan ']},
#  {'id': 781,
#   'captions': ['A man riding water skis on top of a body of water.',
#    'A para sailer leans back and pulls on the rope connected to his sail. ',
#    'A person that is wind surfing in the water.',
#    'The kite surfer is spraying up water as he surfs.',
#    'While a purple/blue sky with what looks like a kite or a loose para-sail floating in it covers most of a distance shot, the bottommost part shows grassy side banks and a body of water with a water skier being pulled.']},
#  {'id': 790,
#   'captions': ['A group of people are gathered around a table with cake on it. ',
#    'Four persons sitting on dining table for cake and drinks. ',
#    'Group around a table waiting for a birthday cake to be served.',
#    'a family is sitting down at a table to have cake',
#    'adults at dining room table with birthday cake.']},
#  {'id': 795,
#   'captions': ['A COUPLE OF PEOPLE JUST GETTING OFF OF A TRAIN \n',
#    'A train passing through a station  on the middle track.',
#    'A yellow train pulling into the train platform filled with people',
#    'Many people are walking with suitcases in a train station.',
#    'Passengers are walking alongside a yellow train inside of a station']},
#  {'id': 797,
#   'captions': ['A couple of elephants being playful with each other.',
#    'Two elephants are play fighting each other in a field.',
#    'Two elephants being playful or aggressive with their trunks.',
#    'Two elephants facing each other and one is touching the other with its trunk',
#    'Two very big elephants playing together in a field.']},
#  {'id': 801,
#   'captions': ['A very large clock tower on the side of a church.',
#    'An old building has a clock tower with a weather vane.',
#    'An old building with a clock at the top of it.',
#    "An old building's clock tower is being displayed.",
#    'The tall clock tower is built into the corner edge of the building.']},
#  {'id': 813,
#   'captions': ['A flock of ducks floating on top of a lake.',
#    'The three ducks are by the water outside.',
#    'Three ducks walking along a dock near the water.',
#    'Three geese that are standing by a pond.',
#    'three ducks next to the shore of a pond']},
#  {'id': 821,
#   'captions': ['A black and white photograph of two men on side of the road.',
#    'Two men by a church and a parking lot.',
#    'Two men outside near a car and moving a cart of some sort.',
#    'Two men standing near each other by some parked cars',
#    'an old black and white photo of two people']},
#  {'id': 825,
#   'captions': ['A cat sleeping on a bed next to a comforter.',
#    'A white cat sleeping on a bed in the sun',
#    'Black and white photograph of a cat snoozing on a bed',
#    'Cat Siamese looking sleeping on its side on a comforter.',
#    'a white cat lying on the bed sleeping']},
#  {'id': 828,
#   'captions': ['A man in a cap on a surf board and holding an oar. ',
#    'A man on a surfboard in the water.',
#    'A man stands on a surf board and holds a paddle.',
#    'A man with a paddle riding a wave on a surfboard.',
#    'Guy in a cap is paddle surfing on a wave']},
#  {'id': 839,
#   'captions': ['A couple of men playing frisbee against each other on a field.',
#    'Two teenagers playing of game of Frisbee in a field.',
#    'Two young men play with a Frisbee in a grassy area.',
#    'Two young men playing frisbee in a park.',
#    'this is two men in cleats on the grass']},
#  {'id': 853,
#   'captions': ['A bowl full of tuna salad next to two slices of bread topped with the salad and one with ketchup on it.',
#    'A sandwich covered in red sac use and chicken salad.',
#    'The sandwich bread is being covered with sauce and salad.',
#    'Two pieces of bread with sauce on them next to a bowl of chicken salad. ',
#    'an image of a chicken salad sandwich being made']},
#  {'id': 882,
#   'captions': ['A dog and his owner on the back of a boat.',
#    'A man holding a puppy on a boat.',
#    'A man holding his dog while on a boat.',
#    'A man on a boat holding his dog in his lap.',
#    'A man riding on a boat on the ocean while holding an adorable bull dog.']},
#  {'id': 897,
#   'captions': ['A person laying on the ground  on a pair of skis. ',
#    'A skier that has fallen in the snow ',
#    'A young man laying on the ground while wearing skis.',
#    'Skier in blue jacket laying down in the snow on their stomach. ',
#    'a person on the ground wearing skis ']},
#  {'id': 901,
#   'captions': ['A busy city street lit up at night in a foreign country.',
#    'A city street has lighted signs and buildings.',
#    'A city street with many tall lighted buildings.',
#    'A downtown city street at night with neon signs.',
#    'A street at night with people walking around and buildings lit up.']},
#  {'id': 902,
#   'captions': ['A bowl filled with fruit on top of a table.',
#    'A bowl of exotic fruit is in a bowl on the table.',
#    'A bowl of fruit is sitting on top of the table.',
#    'A bowl sits on a table, containing bananas and other food.',
#    'Fruit in ceramic bowl on wood table with white walls']},
#  {'id': 908,
#   'captions': ['A frame is attached to a wall near a kitchen.',
#    'A home kitchen with posters from Nashville, Tennessee',
#    'A kitchen with art and a menu hanging on the wall',
#    'A kitchen with signs on the wall outside of it.',
#    'The interior decor in an average kitchen. ']},
#  {'id': 909,
#   'captions': ['A computer is on a desk next to a mess.',
#    'A computer sitting on a desk with candy and drinks by it.',
#    'A computer with an empty bottle, cup and box of crackers beside it.',
#    'A desk with a computer monitor and a keyboard.',
#    'Crackers, Starburst, and a bottle of water are on a desk next to a computer.']},
#  {'id': 913,
#   'captions': ['A airplane that is sitting on a runway.',
#    'A jet sits on display in during an air show.',
#    'Jet plane on tarmac with people and cloudy sky',
#    'Several airplanes sitting on the tarmac at an airport.',
#    'Two jets sit on the tarmac on a sunny day. ']},
#  {'id': 925,
#   'captions': ['A man holding his hands near his balls and wearing a watch.',
#    'A man in a suit and tie sitting with his hands between his legs.',
#    'There is a man with his hands in his lap',
#    'a man from the neck down with a suit and tie on',
#    'there is a man sitting on the train wearing a suit']},
#  {'id': 927,
#   'captions': ['A black and white photo of a little girl on a skate board.',
#    'A little kid that is on a skateboard.',
#    'A young girl riding a skateboard across school yard.',
#    'A young girl wearing a helmet skates on a skateboard.',
#    'Black and white photograph of a happy girl skateboarding']},
#  {'id': 934,
#   'captions': ['People stand by watching a couple elephants taking a nice walk together',
#    'Two elephants in a zoo grazing on leaves.',
#    'Two very big elephants standing together in an enclosure.',
#    'two elephants on a dirt ground near tres',
#    'two elephants standing next to each other on a dirt ground next to trees.']},
#  {'id': 941,
#   'captions': ['A bed with a book, black laptop and blanket.',
#    'A book sitting open and on top of a table.',
#    'An open book beside a computer and some clothing.',
#    'An open book next to a laptop setting on a bed',
#    'a close up of a book near a laptop on a bed']},
#  {'id': 943,
#   'captions': ['A doghouse and dogs sculpted from sand with a toy fire hydrant.',
#    'A red fire hydrant and a sand sculpture on a beach.',
#    'Doghouse and cat made from sand by a toy fire hydrant.',
#    'Someone on the beach has built a sand doghouse.',
#    'people built a dog house shaped sand castle']},
#  {'id': 955,
#   'captions': ['A display filled with luggage and a poster.',
#    'A display of Australia trunks in various sizes',
#    'A display of suite cases behind glass with a poster for Australia in the background. ',
#    'A display setting with a bunch of luggage on a shelf.',
#    'a couple of trunks are in a glass case']},
#  {'id': 960,
#   'captions': ['A woman with a beer is wearing a gray tie.',
#    'a girl is wearing a tie and a dress',
#    'a woman wearing a tie holding onto an almost empty beer ',
#    'there is a woman holding a beer and dancing',
#    'this woman is drinking a beer and dancing']},
#  {'id': 965,
#   'captions': ["A person's legs in the snow wearing a snowboard.",
#    'A persons legs on a snowboard in the snow.',
#    'A snowboarder laying down to show his legs and feet on the snowboard.',
#    'A snowboarder resting by sitting down in the snow.',
#    'a snowboarder in blue pants standing on his snowboard']},
#  {'id': 977,
#   'captions': ['A cat lying on a couch with pillows',
#    'A couple of cats laying on a couch in a room.',
#    'There are three cats laying on a couch.',
#    'Three cats are stretched out on a couch.',
#    'a couple of kitty cats sprawled out on a sofa']},
#  {'id': 982,
#   'captions': ['A Minnie the Mouse cake sits on a cutting board.',
#    'A cake decorated to look like a female mouse.',
#    'A cake of a animated character, with a bow on its head.',
#    'The face of a dog with its tongue sticking out. ',
#    'a close up of a cake made to look like minnie mouse ']},
#  {'id': 984,
#   'captions': ['A pair of hands split a bundle of bananas on top of a box of oranges.',
#    'A person is holding a small bushel of bananas.',
#    'A person pulling apart a bunch of bananas in a box.',
#    "A person pulling apart a bundle of banana's in a crate.",
#    'A person selecting some bananas from a bunch.']},
#  {'id': 996,
#   'captions': ['A couple of giraffe in a fenced in area.',
#    'Some giraffes hanging out together in a fenced area.',
#    'Two giraffes are standing in an enclosed area.',
#    'Two giraffes standing next to each other in a zoo.',
#    'Two giraffes, one adult, one young walk in a fenced area as another lays on the ground.']},
#  {'id': 1006,
#   'captions': ['A man in slippers standing on the side of the street talking on a cell phone.',
#    'A man standing on the sidewalk in his underwear wearing animal slippers.',
#    'A man wearing a leather jacket, shorts and oversized slippers.',
#    'MAN ON CELL PHONE STANDING ON STREET CORNER IN HOUSE SLIPPERS',
#    'a person stading on a city street in shorts and slippers ']},
#  {'id': 1011,
#   'captions': ['A street with people carrying their bags and suitcases ',
#    'An overhead view of several people walking down a street carrying luggage.',
#    'Males and females walking in the street and on the sidewalk with their luggage.',
#    'People are walking along a sidewalk with their luggage.',
#    'a group of people walking next to a building with their suitcases ']},
#  {'id': 1014,
#   'captions': ['A man with his arm around another man.',
#    'Three male tennis players in a tree lined area.',
#    'Two men pose while having a photograph taken.',
#    'Two men posing for a picture in a lot.',
#    'two men standing by each other for a photo']},
#  {'id': 1025,
#   'captions': ['A brown dog on beach surrounded by a heart shape.',
#    'A cute little dog sitting in a heart drawn on a sandy beach.',
#    'A dog sitting in a heart on a beach by ocean',
#    'A heart shaped figure is engraved on sand,in the center of which a dog is sitting.',
#    'a dog sits on a beach inside of a drawn heart']},
#  {'id': 1036,
#   'captions': ['A knife and a fork rest on a plate with vegetables and meat.',
#    'A plate of food with potatoes, vegetables, and meat. ',
#    'A plate that has some steak, potatoes, and some vegetables on it.',
#    "Someone's dinner consisting of brussel sprouts, and meat.",
#    'a plate that has some different kinds of foods']},
#  {'id': 1053,
#   'captions': ['A group of bicycle riders crossing a paved street.',
#    'Cyclists crossing the street in front of a car.',
#    'People wearing helmets while riding bicycles crossing the street.',
#    'Several bicyclists crossing the street at a designated crossing in the roadway.',
#    'some bicycle riders are crossing a street ']},
#  {'id': 1059,
#   'captions': ['A cheesy pepperoni pizza sitting on top of a pan.',
#    'A pepperoni pizza on a plate sitting on a table.',
#    'A pepperoni pizza with extra cheese and pale thick dough. ',
#    'A pizza with pepperonis sitting on a plate on a table.',
#    'A small pizza that appears to have pepperonis on it.']},
#  {'id': 1072,
#   'captions': ['A large passenger jet prepares for a landing in front of a group of mountains.',
#    "A passenger airplane with it's landing gear extended, flying in the sky over a green wooded area and mountains are in the distance.",
#    'A plane flies high over a forest with mountains in the distance. ',
#    'A plane is close to the ground near a mountain and trees.',
#    'a large air plane flying thru the sky with mountains in the background']},
#  {'id': 1084,
#   'captions': ['A bunch of different tools sitting on a table.',
#    'A pair of scissors, pliers and an allen wrench on a table.',
#    'A small group of tools laid out on a table.',
#    'The scissors, the wire cutters and the box knife, are laying on the table.',
#    'Tools arranged on a table: scissors, wire cutters, knife, and hex wrench.']},
#  {'id': 1085,
#   'captions': ['A brown cat curled up sleeping on a human bed.',
#    'A cat is laying on a bed with blue sheets.',
#    'A cat sleeping on a bed with a pillow',
#    'An orange cat laying on a bed with a black comforter.',
#    'a brown cat sleeping on a bed with a blue blanket']},
#  {'id': 1090,
#   'captions': ['A train riding through a town by a large mountain.',
#    'A train station near a snowy mountain belt. ',
#    'A train traveling along a building covered hillside.',
#    'a beautiful train moving besides residential houses and mountains',
#    'a train with buildings with a mountain in the background']},
#  {'id': 1098,
#   'captions': ['A woman is petting a cow at a petting zoo. ',
#    'A woman kneeling down to pet a black and white cow laying on the ground.',
#    'A young woman petting a cow thats laying down.',
#    'a person kneeling down petting a small cow',
#    'a woman kneeling next to a cow laying on the ground']},
#  {'id': 1099,
#   'captions': ['A photograph of a bathroom inside a home.',
#    'The bathroom has a toilet, sink, and mirror in it.',
#    'The light shines brightly from a window in the small bathroom.',
#    'There is a missing door of a bathroom.',
#    'the bathroom is white and has brown tiles on the floor']},
#  {'id': 1102,
#   'captions': ['A person standing on the snow next to a tree.',
#    'A person with a snow board is standing in a snowy field.',
#    'A skier out on the snow with his skis.',
#    'A young person with a slide in the middle of a snowy yard.',
#    'The person is slowly making their way through the snow,']},
#  {'id': 1107,
#   'captions': ['A small plane is hanging in the hanger',
#    'A vintage propeller plane hanging in a display.',
#    'A war plane hangs in the air of the airplane hanger.',
# ...
#    'A tall giraffe towering over a forest filled with trees.',
#    'LARGE GIRAFFE STANDING STILL WITH SOME TREES AROUND']},
#  {'id': 7048,
#   'captions': ['A group of seagulls standing near the ocean water.',
#    'Five birds standing in the sand near a body of water.',
#    'Flock of birds standing on a shore line of a beach.',
#    'a small group of ducks on the edge of water',
#    'five gray and white birds sand and water']},
#  {'id': 7049,
#   'captions': ['A black and white image of an older lady holding an umbrella. ',
#    'A person walking on a street with a umbrella.',
#    'An elderly woman carries an umbrella in the rain.',
#    'An elderly women walking with an umbrella. ',
#    'Elderly woman walking in rain carrying umbrella near pedestrian.']},
#  {'id': 7069,
#   'captions': ['A man holding a yellow frisbee in front of a park sign.',
#    'A man is holding a frisbee on a trail mark. ',
#    'A man stands next to a sign in a forested area while holding a frisbee.\n',
#    'a man holding a frisbee next to a sign attached to a wooden post.',
#    'a man holding a frisbee standing next to a sign']},
#  {'id': 7090,
#   'captions': ['The pizza for lunch are on the trays. ',
#    'Two slices of pizza on a tray with a drink. ',
#    'Two slices of pizza on top of a white plate.',
#    'Two slices of pizza sitting on a white plate with soda near it. ',
#    'two red trays with pizza and a cup of soda ']},
#  {'id': 7095,
#   'captions': ['A brick building with a black and white awning',
#    'A building with a striped awning and a tree in front.',
#    'A red brick building has round decorations at the top.',
#    'A store front with a black and white awning on a snowy street.',
#    'A turn of the century styled building has a black and white awning. ']},
#  {'id': 7103,
#   'captions': ['A girl is lying down and talking on her phone.',
#    'A girl lays down while on the phone.',
#    'A woman reclines and looks at the camera as she talks on a cell phone.',
#    'A woman talks on the cell phone while smiling. ',
#    'A woman with a cell phone to her ear sharing a smile.']},
#  {'id': 7104,
#   'captions': ['A man in a crowded street eating a very long hot dog.',
#    'A man is eating a large hot dog in the street.',
#    'A man is eating beside a busy street.',
#    'Man eating long hot dog on street corner in city.',
#    'Man wearing a red shirt and shorts eating on a busy street. ']},
#  {'id': 7116,
#   'captions': ['A couple of small boats are on the lake.',
#    'Boats sit in the lake next to one another.',
#    'Motor and photon boats moored in the water.',
#    'Several boats out on a lake during an overcast day.',
#    'a few small boats in a large body of water']},
#  {'id': 7123,
#   'captions': ['A man is in water enjoying a day of water skiing. ',
#    'A man on a small water board tries to stay afloat.',
#    'A person on a surfboard in the water.',
#    'A person on a water board rides on the water.',
#    'A wind surfer riding a few waves on the water.']},
#  {'id': 7124,
#   'captions': ['A meter made standing next to a parking meter.',
#    'A meter maid checking a meter on the side of the road.',
#    'A policeman printing out a parking violation ticket.',
#    'Security officer holding a typing device next to a parking meter.',
#    'There is a police officer writing a ticket for a truck.']},
#  {'id': 7129,
#   'captions': ['Two boys are skiing in snow in front of a mountain.',
#    'Two kids are on skis at the top of a slope.',
#    'Two people in ski gear with a mountain in the background.',
#    'Two people who are wearing snow skis on snow.',
#    'Young children on snowy area of alpine region.']},
#  {'id': 7139,
#   'captions': ['A green cart with red wheels carries several suitcases.',
#    'A trolley sits unattended while loaded with baggage.',
#    'A wooden cart outside of a hotel loaded with guests luggage.',
#    "An old green wagon holds someone's modern luggage",
#    'a pulling cart with a bunch of cargo on the back']},
#  {'id': 7143,
#   'captions': ['A large airplane high up in the sky.',
#    'A plane flying against a blue sky above blue water.',
#    'An airplane is flying over nice blue water.',
#    'Jet flying in a blue sky over blue water.',
#    'an airplane flying above the water and a house ']},
#  {'id': 7145,
#   'captions': ['A giant pizza that has not been eaten yet.',
#    'A pizza that has cheese and various types of toppings on it.',
#    'A pizza that is sitting on a table.',
#    'A pizza with yellow and red peppers and mushrooms on a white surface',
#    'a fork and a pizza with red and yellow toppings']},
#  {'id': 7150,
#   'captions': ['A cat is laying down on top of a chair.',
#    'A cat laying down on a chair cushion.',
#    'A white cat curled up on a wooden chair.',
#    'The cat is curled up on the kitchen chair.',
#    'there is a cat that is laying down on top of a chair']},
#  {'id': 7159,
#   'captions': ['A person makes a ski jump off a hill while other skiers look on.',
#    'A vintage picture of several people watching and filming a skier mid-jump.',
#    'Black and white photograph of people skiing in a competition',
#    'Several people that are skiing in the snow.',
#    'Two ski competitors watching another competitor come down the hill.']},
#  {'id': 7167,
#   'captions': ['A small bedroom that is simply decorated and furnished.',
#    'The bed is sitting in small room with two nightstands.',
#    'There is a bed sitting in a small room.',
#    'This bed is neatly made with the pillows on top of the covers. ',
#    'a bed with two pillows sits next to a dresser ']},
#  {'id': 7174,
#   'captions': ['A farm filled with horses at the base of a tall mountain.',
#    'A large horse ranch sits in front of a mountainous terrain.',
#    'A lot of animals that are in the grass.',
#    'A mountainous desolate landscape full of multi-color horses',
#    'Many horses stand in a fenced area in front of barren mountains. ']},
#  {'id': 7179,
#   'captions': ['A table is laden with supplies such as peppers, brown and white eggs, tomatoes, milk, corn and grapes.',
#    'A variety of healthy foods arranged on a table top. ',
#    'A wooden table topped with vegetables and eggs.',
#    'There are eggs, fruit, and milk on the cutting board.',
#    'Vegetables , salad dressing and a dozen of eggs arranged on a table. ']},
#  {'id': 7201,
#   'captions': ['A car with surfboards on the roof driving on the beach.',
#    'A yellow SUV driving on a sandy beach next.',
#    'A yellow car driving on the beach by the ocean.',
#    'A yellow s.u.v is driving on the beach',
#    'Orange truck with a surfboard on it driving on the beach. ']},
#  {'id': 7205,
#   'captions': ['A giraffe on an empty field near a couple of palm trees. ',
#    'A giraffe standing in grass in a palm tree filled environment',
#    'A giraffe walks near some palm trees in the garden.',
#    'A tall giraffe standing in a field next to trees',
#    'A tall giraffe stands alone near a few trees.']},
#  {'id': 7220,
#   'captions': ['A wooden table with two plates of breakfast foods.',
#    "It's a hearty breakfast of bacon and eggs.",
#    'Some food is layed out on a table',
#    'Three plates of food and several drinks are on a table.',
#    'a table with plates drinks tomatoes bacon and eggs ']},
#  {'id': 7221,
#   'captions': ['A naked baby chewing on a toothbrush on the floor',
#    'A naked baby is chewing on a toothbrush on the floor in a bathroom.',
#    'A naked baby is lying on a white towl.',
#    'A naked baby lays on a towel in a bathroom and chews on a toothbrush.',
#    'a naked baby laying on a bed chewing on a toothbrush']},
#  {'id': 7224,
#   'captions': ['A display of a family of bears at the museum.',
#    'Baby bear cub up in a tree while mom and another cub are below.',
#    'Three statues of bears with one climbing on a log.',
#    'Two brown bears in a wilderness scene, one climbing a tree and one walking',
#    'Two dead stuffed brown bears on display at a museum.']},
#  {'id': 7228,
#   'captions': ['A group of people crossing a street at a cross walk.',
#    'A group of walkers and bikers crossing the street.',
#    'A pedestrian crosswalk with bikers and walkers crossing it.',
#    'Several people, some on bikes, some on foot, crossing a street at a crosswalk. ',
#    'a group of people walking across the street ']},
#  {'id': 7232,
#   'captions': ['A train is traveling on a straight runway rail. ',
#    'A train makes its way down the tracks past some trees.',
#    'A train traveling through a lush green countryside.',
#    'a train on a train track wit ha sky background',
#    'a yellow orange black train engine and its cars']},
#  {'id': 7239,
#   'captions': ['A hand held mirror hanging on the wall.',
#    'A magnifying mirror hanging from a hook on the wall in the bathroom.',
#    'A mirror hanging on the wall reflecting a toothbrush. ',
#    'A mirror is hanging on the wall with a blurred reflection.',
#    'A mirror is hung a wall with a reflection of a toothbrush.']},
#  {'id': 7247,
#   'captions': ['A white and orange cat and a black, orange and white cat sleeping in front of each other. ',
#    'An orange and white cat laying on top of a floor.',
#    'Two cats face to face laying down next to one another on a wooden base.',
#    'Two cats on a table in a room',
#    'Two cats touching each other face to face.']},
#  {'id': 7251,
#   'captions': ['A closeup of two bananas and two baskets.',
#    'Joined ends of pair of bananas pictured over basket.',
#    'The ends of two bananas are sticking out of a basket.',
#    'There are a few bananas left by the chair. ',
#    'Tip of banana stem over a basket lid']},
#  {'id': 7275,
#   'captions': ['A guy skateboarding on a big ramp somewhere.',
#    'A man on ski board is in the air trying to pull off a trick. ',
#    'A man snowboarding in the air off a slope.',
#    'A person doing a trick on their snowboard form a ramp.',
#    'A person on a snow board flying high in the air.']},
#  {'id': 7277,
#   'captions': ['A man and a woman playing a video game.',
#    'A man playing a game while the woman is carrying a bag.',
#    'A man playing with a Wii controller next to a woman wearing a green purse. ',
#    'These two people are playing video games together. ',
#    'Two young adults plat a video game in a room. ']},
#  {'id': 7307,
#   'captions': ['A man is playing tennis while people watch.',
#    'A man playing tennis while many spectators look on.',
#    'A person on a court with a tennis racket.',
#    'A woman is swinging a tennis racket at a game',
#    'a man standing on one foot while playing a game of tennis ']},
#  {'id': 7318,
#   'captions': ['A woman getting ready to eat some delicious hotdogs.',
#    'A woman in black shirt sticking tongue out above tray of chili dogs.',
#    'A woman licking down at a plate of hot dogs.',
#    'A women with her tongue out looking at two hot dogs.',
#    'There is a woman taking a picture with two hot dogs']},
#  {'id': 7319,
#   'captions': ['A black cat is drinking water from a sink.',
#    'A black cat licks water from a sink. ',
#    'A cat that is drinking water from a sink.',
#    'A furry cat drinking water from a sink',
#    'a black cat drinking water out of a sink ']},
#  {'id': 7357,
#   'captions': ['A person snowboarding down a rocky mountain ',
#    'One person stands on a rock edge in a snowy area while another person descends from it.',
#    'The snowboarder was leaping off some rocks onto the snow below.',
#    'Two guys making dangerous jumps off a cliff.',
#    'a person riding a snow board in the air ']},
#  {'id': 7361,
#   'captions': ['A building with a clock and red and yellow flags. ',
#    'A grey wall with a clock next to flags and windows.',
#    'A massive clock mounted to the side of a building.',
#    'An old fashioned clock mounted on the side of a building. ',
#    'a building with a large intricate clock on it ']},
#  {'id': 7367,
#   'captions': ['A bowl of moldy fruit is arranged in a bowl.',
#    'A bright blue bowl full of assorted fruits.',
#    'An orange, banana, mango on a blue plate',
#    'There are plenty of fruit still left in the bowl. ',
#    'Variety of fruits displayed in blue toned container.']},
#  {'id': 7393,
#   'captions': ['A couple of giraffe standing in a field.',
#    'A couple of giraffes are standing together in the dirt. ',
#    'There are two giraffes and two lions on the path. ',
#    'Three giraffes standing dangerously close to two lions.',
#    'some giraffes and lions a hill rocks and trees and bushes']},
#  {'id': 7396,
#   'captions': ['A duo of train engines coming into a station down some tracks.',
#    'The yellow train is going faster than the other train.',
#    'Two fast moving transits with a read, yellow and green paint scheme. ',
#    'Two trains emerging from an enclosed, dark station.',
#    'two trains ride next to each other on some tracks ']},
#  {'id': 7420,
#   'captions': ['A  couple making the first cut into a wedding cake',
#    'A bride and groom cut the cake together.',
#    'A woman in a white wedding dress cutting a wedding cake.',
#    'a bride and groom cutting in to their wedding cake\n',
#    'an image of a wedding couple cutting their wedding cakes']},
#  {'id': 7424,
#   'captions': ['A man taking a photograph of himself in the mirror.',
#    'A man taking a selfie of hiself in a mirror.',
#    'A man uses his phone to take a selfie.',
#    'A man wearing a suit and tie taking a selfie with his cellphone.',
#    'A young man in a suit taking a picture of his reflection in a mirror with his phone.']},
#  {'id': 7452,
#   'captions': ['A man riding a surfboard in the water',
#    'A surfer is in the middle of catching a wave.',
#    'A surfer riding a wave in the ocean.',
#    'A surfer riding the waves on a surfboard',
#    'Surfer taking a wave on a surf board.']},
#  {'id': 7455,
#   'captions': ['A couple of boats parked at the wharf during the day.',
#    'An old marina full of yachts and motor boats',
#    'Boats docked at a marina by a city.',
#    'Many boats of various sizes sit in a blue harbor. ',
#    'a group of boats sitting in a harbor waiting to be taken out']},
#  {'id': 7476,
#   'captions': ['A couple of blue bottles sitting next to a green vase.',
#    'Bottles have different colors and are shiny ',
#    'Two blue bottle in front of a green vase',
#    'Two blue glass bottles and a green glass in the center.',
#    'Two blue glass bottles in front of a green glass vase.']},
#  {'id': 7489,
#   'captions': ['A commercial airline plane mid air during day light.  ',
#    'A large commercial airplane flying in a clear sky',
#    'A large passenger jet flying through a blue sky.',
#    'An airplane is flying high in the sky ',
#    'an airplane is flying through the air ']},
#  {'id': 7498,
#   'captions': ['The backsides of two elephants walking side by side.',
#    'The two huge elephants are walking side by side',
#    'Two elephants standing next to each other in front of a face.',
#    'Two very plump elephants walking near a wire fence.',
#    'a pair of elephants inside of an enclosure']},
#  {'id': 7500,
#   'captions': ['A line of people walking down the street holding onto kites.',
#    'A young man is carrying two colorful kites.',
#    'People are walking down a road and holding kites. ',
#    'People on a street with color full kites.',
#    'some people are walking down a road holding kites']},
#  {'id': 7503,
#   'captions': ['A man in shorts is playing tennis backed by a fence.',
#    'A man swinging a tennis racquet at a tennis ball.',
#    'A man taking a swing at a tennis ball.',
#    'A tennis player in  the motion of hitting the ball back.',
#    'Man poised to hit a backhand tennis shot']},
#  {'id': 7504,
#   'captions': ['There are three clocks hanging on the wall.',
#    'Three clocks on a pink wall reflect different time zones.',
#    'Three clocks on a wall showing the time of different cities in Asia.',
#    'Three clocks on a wall, telling different times on it.',
#    'three different clocks  on a wall with different time zones']},
#  {'id': 7510,
#   'captions': ['A smoking train going down the railroad tracks.',
#    'A steam powered train traveling through a rural countryside.',
#    'A train is traveling down the track near trees.',
#    'There is a great amount of steam coming from the train.',
#    'an old steam engine coming down the tracks']},
#  ...]

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### Text: Captions

# %%
annotation_list_train = []
annotation_list_val = []
annotation_list_test = []

for data in annotations_data_train:
    annotation_list_train += data["captions"]
    
annotation_list_train = ["<start> " + annotation + " <end>" for annotation in annotation_list_train]

for data in annotations_data_val:
    annotation_list_val += data["captions"]
    
annotation_list_val = ["<start> " + annotation + " <end>" for annotation in annotation_list_val]
    
for data in annotations_data_test:
    annotation_list_test += data["captions"]

annotation_list_test = ["<start> " + annotation + " <end>" for annotation in annotation_list_test]

# %%
print("Caption count train: ",len(annotation_list_train))
print("Caption count val: ",len(annotation_list_val))
print("Caption count test: ",len(annotation_list_test))
# Out:
# Caption count train:  541714
# Caption count val:  25021
# Caption count test:  50032

# %%
annotation_list_train
# Out:
# ['<start> A bunch of trays that have different food. <end>',
#  '<start> A meal is presented in brightly colored plastic trays. <end>',
#  '<start> Closeup of bins of food that include broccoli and bread. <end>',
#  '<start> Colorful dishes holding meat, vegetables, fruit, and bread. <end>',
#  '<start> there are containers filled with different kinds of foods <end>',
#  '<start> A giraffe eating food from the top of the tree. <end>',
#  '<start> A giraffe mother with its baby in the forest. <end>',
#  '<start> A giraffe standing next to a forest filled with trees. <end>',
#  '<start> A giraffe standing up nearby a tree  <end>',
#  '<start> Two giraffes standing in a tree filled area. <end>',
#  '<start> A flower vase is sitting on a porch stand. <end>',
#  '<start> A vase with red and white flowers outside on a sunny day. <end>',
#  '<start> A white vase filled with different colored flowers. <end>',
#  '<start> White vase with different colored flowers sitting inside of it.  <end>',
#  '<start> a white vase with many flowers on a stage <end>',
#  '<start> A lone zebra grazing in some green grass. <end>',
#  '<start> A zebra grazing on lush green grass in a field. <end>',
#  '<start> The zebra is eating grass in the sun. <end>',
#  '<start> Zebra reaching its head down to ground where grass is.  <end>',
#  '<start> a Zebra grazing on grass in a green open field. <end>',
#  '<start> A girl in a bathing suit with a pink umbrella. <end>',
#  '<start> A woman in a floral swimsuit holds a pink umbrella. <end>',
#  '<start> A woman posing for the camera, holding a pink, open umbrella and wearing a bright, floral, ruched bathing suit, by a life guard stand with lake, green trees, and a blue sky with a few clouds behind. <end>',
#  '<start> A woman with an umbrella near the sea <end>',
#  '<start> Woman in swim suit holding parasol on sunny day. <end>',
#  '<start> A couple of men riding horses on top of a green field. <end>',
#  '<start> A pair of horses performing tricks in a field.  <end>',
#  '<start> Two costumed horse riders make their horses stand on their hind legs. <end>',
#  '<start> Two men are on horses that are reared back. <end>',
#  '<start> two horses and their riders on some grass <end>',
#  '<start> SOME PEOPLE IN THE WOODS RIDING TWO ELEPHANTS <end>',
#  '<start> Several elephants in the jungle carrying people on their backs <end>',
#  '<start> Some people who are riding on top of elephants. <end>',
#  '<start> They are brave for riding in the jungle on those elephants. <end>',
#  '<start> there are people riding elephants in the middle of a forest <end>',
#  '<start> A clock is seen in front of a tall tree. <end>',
#  '<start> A clock sits on top of a black pole near a tree on a sidewalk near a crosswalk. <end>',
#  '<start> A pole with a clock that reads 6:10 by a white car.  <end>',
#  '<start> A very pretty clock on the side of a road. <end>',
#  '<start> a black and silver clock tower at an intersection near a tree <end>',
#  '<start> A passenger train glides around a curve on the outer track. <end>',
#  '<start> A train coming down the tracks in the city. <end>',
#  '<start> A train coming to a stop on the tracks out side. <end>',
#  '<start> A train engine carrying many carts down a track. <end>',
#  '<start> The very long train is travelling down the tracks. <end>',
#  '<start> A couple of giraffe snuggling each other in a forest. <end>',
#  '<start> A couple of giraffe standing next to some trees. <end>',
#  '<start> The two giraffes appear to be hugging each other. <end>',
#  '<start> Two Zebras seem to be embracing in the wild.  <end>',
#  '<start> Two giraffes hang out near trees and nuzzle up to each other. <end>',
#  '<start> A time lapse image of a guy on a skate board. <end>',
#  '<start> A young man riding a skateboard into the air. <end>',
#  '<start> Group of boys performing skateboard trick on ramp with graffiti on it <end>',
#  '<start> a group of teenagers jumping a ramp on their skateboards <end>',
#  '<start> some male skateboarders are doing some tricks and grafitti <end>',
#  '<start> A lighted owl candle sits next to a clock. <end>',
#  '<start> An antique looking clock beside an owl with a candle in it. <end>',
#  '<start> An owl candle and a clock sitting in front of a wall. <end>',
#  '<start> White clock sitting next to a statue of an owl.  <end>',
#  '<start> a close up of a clock near an owl candle holder  <end>',
#  '<start> A big airplane flying in the big blue sky <end>',
#  '<start> A big plane with AirFrance on the side of it. <end>',
#  '<start> An Air France air plane in mid flight. <end>',
#  '<start> An AirFrance jet airplane flying in the sky  <end>',
#  '<start> Large, two decked, four engined airliner in flight. <end>',
#  '<start> A man on a an old fashioned bicycle in the woods  <end>',
#  '<start> A man riding a motor bike across a forest. <end>',
#  '<start> A man sitting on a motorcycle in the woods. <end>',
#  '<start> A person looks down at something while sitting on a bike.  <end>',
#  '<start> A young person is on a very ornate old bicycle. <end>',
#  '<start> A small light is on above the polished stove top. <end>',
#  '<start> A stove top is cleaned with a set of knives on the wall. <end>',
#  '<start> A stove with a lighted hood in the kitchen. <end>',
#  '<start> An oven with a stove on top of it in a kitchen. <end>',
#  '<start> Smooth top stove with exhaust fan that has light turned on. <end>',
#  '<start> A chocolate desert on a plate with a fork.  <end>',
#  '<start> A piece of chocolate cake on top of a white plate. <end>',
#  '<start> A piece of chocolate dessert on a plate with a napkin and a fork. <end>',
#  '<start> A white plate with a brownie and white frosting. <end>',
#  '<start> a chocolate cake and a fork ready to be eat <end>',
#  '<start> A city street with a sign that reads "Peace Way Hotel". <end>',
#  '<start> A street sign and a car on the road. <end>',
#  '<start> There is a car driving down a street with buildings on each side. <end>',
#  '<start> There is a street lined with packed buildings <end>',
#  '<start> This is a view of a quaint city street. <end>',
#  '<start> A skate park next to a body of water and green park. <end>',
#  '<start> A waterfront walkway and garden area next to a river. <end>',
#  '<start> A wide walkway allows for walks along the river. <end>',
#  '<start> Sky view of a walkway along the shore of a river. <end>',
#  '<start> some grass and a person in a blue shirt walking a dog and water <end>',
#  '<start> A lady and a child are sitting.The lady is cutting pizza pieces. <end>',
#  '<start> A woman and child sitting at a table with a pizza in front of them. <end>',
#  '<start> A woman cutting a pizza with a fork and knife  <end>',
#  '<start> A woman cutting a pizza with a fork and knife. <end>',
#  '<start> Woman cutting pizza with fork and knife sitting next to young girl <end>',
#  '<start> A man and woman standing in front of a cake. <end>',
#  '<start> A woman cutting into a cake with a man standing behind her <end>',
#  '<start> A women who is cutting into a cake. <end>',
#  '<start> a man and woman cut into a big cake  <end>',
#  '<start> two people standing near a table with a cake  <end>',
#  '<start> A dessert and a cup of coffee sit next to a book and a purse. <end>',
#  '<start> A piece of cake and coffee are on an outdoor table. <end>',
#  '<start> A slice of cake and mug sitting on a wooden table outside. <end>',
#  '<start> Slice of cake next to large filled cup on wooden table. <end>',
#  '<start> a close up of a slice of cake on a plate <end>',
#  '<start> A series of photographs of a tiny model kitchen <end>',
#  '<start> Collage of pictures from a clean rustic kitchen.  <end>',
#  '<start> Picture of a kitchen this has smaller photos of item within that kitchen.  <end>',
#  '<start> The kitchen has odd looking colors in it. <end>',
#  '<start> Three dimensional rendering of a kitchen area with various appliances.  <end>',
#  '<start> A sliced banana topped dessert sits on a plate. <end>',
#  '<start> Plate with a piece of bread, dark chocolate spread, bananas and a carton of Silk. <end>',
#  '<start> There is a plate of banana and chocolate on bread <end>',
#  '<start> a close up of a plate of a jelly and banana sandwich <end>',
#  '<start> bread with banana milk and nutella on a table <end>',
#  '<start> Three giraffes standing in the dirt in a fenced in area. <end>',
#  '<start> Three giraffes stuck behind the confines of a zoo fence.  <end>',
#  '<start> Two giraffes eating together out of a trough in a fenced area. <end>',
#  '<start> a couple of giraffes eat some food out of a trey  <end>',
#  '<start> a number of giraffes near one another  <end>',
#  '<start> A host of kites being flown on a field by people. <end>',
#  '<start> People are flying kites on a high school field. <end>',
#  '<start> People flying kites in a field on a cloudy day. <end>',
#  '<start> People gathered outside in a big field on a cloudy day <end>',
#  '<start> a bunch of people are at a grass field  <end>',
#  '<start> A man leans out of a vehicle near a short stop sign in a forest. <end>',
#  '<start> A stop sign directs pedestrians as a train travels by. <end>',
#  '<start> A stop sign is shown close to the ground. <end>',
#  '<start> A stop sign sits in the middle of the forest.  <end>',
#  '<start> A stop sign sitting near some tall trees. <end>',
#  '<start> Three zebra are walking through the grass of a field. <end>',
#  '<start> Three zebras are standing in an open field. <end>',
#  '<start> Three zebras grazing in green grass field area. <end>',
#  '<start> Three zebras standing on a grassy dirt field. <end>',
#  '<start> three zeebras standing in a grassy field walking <end>',
#  '<start> A funny picture of a woman holding a large pair of scissors attempting to cut a mans tie. <end>',
#  '<start> A man in a suit and a woman in military clothes. <end>',
#  "<start> A woman in a soldier's uniform pretends to cut the tie of a man using an enormous pair of scissors. <end>",
#  "<start> A woman soldier holding up a pair of giant scissors to someone's tie. <end>",
#  "<start> a female in military uniform cutting a businessman's neck tie <end>",
#  '<start> A small personal sized pizza is shown on display. <end>',
#  '<start> An exotic pizza sits on a plate, with cheese and bits of meat on top. <end>',
#  '<start> Small pizza sitting on a white plate with different toppings on it.  <end>',
#  '<start> The pizza is loaded with lots of toppings. <end>',
#  '<start> a small pizza that is on a white plate <end>',
#  '<start> A row of snow boards sticking out of the snow. <end>',
#  '<start> Five skateboards on a rack in a snow covered mountain  <end>',
#  '<start> Six snowboards are propped in the snow on a rail. <end>',
#  '<start> Snowboards sticking in the snow by a rack  <end>',
#  '<start> There are skateboards leaning on a metal bar. <end>',
#  '<start> A red, white and blue helicopter has a tag on one blade. <end>',
#  '<start> A small engine plane sitting on an air field being displayed. <end>',
#  '<start> A small plane with a certificate on the propellers. <end>',
#  '<start> a plane sits on a runway waiting for lift off <end>',
#  '<start> a small airplane that is on a runway <end>',
#  '<start> A Greenwich street and Vesey street sign are hanging on a pole. <end>',
#  '<start> A city street has an intersection sign on a pole. <end>',
#  '<start> A street sign on a pole on a street. <end>',
#  '<start> Street signs near tall buildings on the corner of Greenwich St and Vesey St. <end>',
#  '<start> Two green and white street signs with building in background. <end>',
#  '<start> A female traveler leaning on a luggage cart. <end>',
#  '<start> A woman is waiting with a cart full of luggage. <end>',
#  '<start> A woman next to a cart of luggage at a bus stop. <end>',
#  '<start> A woman wearing a yellow shirt standing next to luggage. <end>',
#  '<start> the woman is standing with her luggage  <end>',
#  '<start> A baby elephant tries to get on top of another elephant.  <end>',
#  '<start> A couple of elephants playing with each other in their pen. <end>',
#  '<start> A couple of elephants standing next to each other. <end>',
#  '<start> Adult elephant pushing a baby elephant with its leg. <end>',
#  '<start> One adult and one small elephant in a dry lot. <end>',
#  '<start> A brown and white dog chasing a blue and yellow frisbee. <end>',
#  '<start> A collie chasing a frisbee in the grass. <end>',
#  '<start> A cute dog is in the grass with a frisbee. <end>',
#  '<start> A dog that is standing in the grass near a frisbee. <end>',
#  '<start> The dog is playing with his toy in the grass <end>',
#  '<start> A man pouring wine from casks for patrons <end>',
#  '<start> Group of people tasting wine next to some barrels. <end>',
#  '<start> People are gathered around a man tasting wine. <end>',
#  '<start> People gather around a table while sampling wine. <end>',
#  '<start> the people are sampling wine at a wine tasting. <end>',
#  '<start> A dog stands in the grass next to a stuffed bear. <end>',
#  '<start> A small brown stuffed bear laying in the grass. <end>',
#  '<start> A stuffed bear that is laying down in the grass. <end>',
#  '<start> A teddy bear is laying on the green grass next to a dog.  <end>',
#  '<start> A teddy bear lays on the lawn and a dog stands behind it. <end>',
#  '<start> A baby elephant walks through the forest with five adult elephants. <end>',
#  '<start> A herd of elephants one running with a baby. <end>',
#  '<start> A herd of elephants, including a tiny baby elephant, cross a dirt road. <end>',
#  '<start> A large group of elephants crossing a dirt path. <end>',
#  '<start> Four large elephants are watching over their baby in the wilderness. <end>',
#  '<start> Beautiful women wearing bikinis frolicking on a sandy beach. <end>',
#  '<start> Groups of people sit on a beach in the sand. <end>',
#  '<start> People sunbathing and sitting under umbrellas at a city beach. <end>',
#  '<start> Women are walking towards seats on the beach. <end>',
#  '<start> people in bikinis at a beach under umbrellas <end>',
#  '<start> A sub sandwich in a box next to two hot dogs. <end>',
#  '<start> The takeout containers hold two hot dogs with condiments, and a steak sandwich. <end>',
#  '<start> Two styrofoam carryout containers, one with a steak sub with jalapeno peppers, and the other with two hot dogs. <end>',
#  '<start> a close up of a plastic container with hot dogs <end>',
#  '<start> two plastic containers holding onto a sandwich and hot dogs  <end>',
#  '<start> A full view of a man throwing a Frisbee. <end>',
#  '<start> A man tossing an orange frisbee on top of a lush green field. <end>',
#  '<start> A person is throwing a Frisbee at night.  <end>',
#  '<start> Man playing with flying red disk outdoors in evening. <end>',
#  '<start> a man standing in a yard with a red frisbee <end>',
#  "<start> A man holding a glass of wine on it's side. <end>",
#  '<start> A man tilting a glass of wine.to the side. <end>',
#  '<start> A man tips a clear wine glass to observe its makeup.  <end>',
#  '<start> A person holding a partially filled wine glass. <end>',
#  '<start> a male in a white shirt is holding a glass of wine <end>',
#  '<start> A bowl of pasta, carrots, egg roll and cabbage. <end>',
#  '<start> A plate of food: meat, noodles, sprouts, carrots and salad <end>',
#  '<start> Asian noodles, cut up egg roll with greens and carrots in a white bowl. <end>',
#  '<start> Food in a bowl with carrots and drinks around it <end>',
#  '<start> Healthy foods being used to create a dinner dish. <end>',
#  '<start> A lone train sits on the train track under the bridge. <end>',
#  '<start> A trailer is sitting under a bridge and some power lines. <end>',
#  '<start> A white and orange train passing by trees and a lamppost. <end>',
#  '<start> An old train drives on the tracks under a bridge.  <end>',
#  '<start> The passenger train has stopped at a station. <end>',
#  '<start> A group of kids playing soccer on a field. <end>',
#  '<start> A young boy playing soccer on a grassy field <end>',
#  '<start> A young man kicking a soccer ball around a field. <end>',
#  '<start> Small child in soccer uniform kicking at yellow ball.  <end>',
#  '<start> There are several young boys practicing soccer, some with their dads. <end>',
#  '<start> A little girl holding wet broccoli in her hand.  <end>',
#  '<start> A little girl holds a hand full of wet broccoli.  <end>',
#  '<start> A little girl holds a piece of broccoli towards the camera. <end>',
#  '<start> The young child is happily holding a fresh vegetable.  <end>',
#  '<start> a small kid holds on to some vegetables  <end>',
#  '<start> A distance shot shows rolling snowy hills, partially shadowed, with ski prints reaching off into the distance, and to the foreground, a single skier.  <end>',
#  '<start> A high mountain of snow with a cross country skier. <end>',
#  '<start> A man riding skis down a snow covered slope. <end>',
#  '<start> A mountain slope photo with a person on skis in the foreground. <end>',
#  '<start> landscape of a snowy mountain with a skiers trail in the snow <end>',
#  '<start> A living room filled with furniture and windows covered in curtain. <end>',
#  '<start> A living room with a couch, coffee table and two large windows with white curtains. <end>',
#  '<start> A living room with a couch, coffee table and two windows. <end>',
#  '<start> This is a living room with white curtains. <end>',
#  '<start> a living room with white curtains and a black couch and table <end>',
#  '<start> A man with a bushy beard and green tie. <end>',
#  '<start> A man with a long grey beard in a white shirt and green tie at a pub full of green-shirted patrons. <end>',
#  '<start> A woman standing in a large group of people near stairs. <end>',
#  '<start> The man smiles wearing a green neck tie near a crowd of people.  <end>',
#  '<start> This man is very happy to be at the gathering. <end>',
#  "<start> A white dog has a purple Frisbee in it's mouth. <end>",
#  "<start> A white dog holding a purple frisbee in it's mouth. <end>",
#  '<start> A white dog is holding a frisbee in its mouth waiting to play. <end>',
#  '<start> White dog carrying a purple frisbee on a lawn. <end>',
#  '<start> a dog is holding a frisbee standing on grass <end>',
#  '<start> A pair of boats docked at a pier is shown. <end>',
#  '<start> Three boats are docked together on the cloudy day. <end>',
#  '<start> Three boats docked in still water with clouds in the sky.  <end>',
#  '<start> a couple of boats that are in some water <end>',
#  '<start> some colorful boats sitting next to a dock  <end>',
#  '<start> A tennis player taking  a swing at  a ball <end>',
#  '<start> Two people at a public tennis court; one serves the ball. <end>',
#  '<start> Two people on the tennis court playing tennis <end>',
#  '<start> Two people playing tennis in a neighborhood park.  <end>',
#  '<start> two people playing tennis on a tennis court. <end>',
#  '<start> A male tennis player hits the ball on a grass court. <end>',
#  '<start> A man in motion hitting a tennis ball with a tennis racket on a tennis court. <end>',
#  '<start> A tennis player in action on the court. <end>',
#  '<start> a male in a white shirt is playing tennis <end>',
#  '<start> a man that is playing tennis on a court <end>',
#  '<start> A man is eating a roll and licking his thumb. <end>',
#  '<start> A man licking his thumb with a peanut buttered bread slice in his hand. <end>',
#  '<start> A person licks his thumb while holding a piece of food. <end>',
#  '<start> Man wearing glasses eating a slice of food. <end>',
#  '<start> there is a person sitting and licking their fingers <end>',
#  '<start> A big box of various types of doughnuts. <end>',
#  '<start> A box full of donuts in different shapes and flavors. <end>',
#  '<start> A box of chocolate, filled, sour cream donuts. <end>',
#  '<start> A variety of donuts and pastries in a box. <end>',
#  '<start> Various pastries are displayed in a take out box. <end>',
#  "<start> A cat is lying on its back in a man's lap. <end>",
#  '<start> A cat laying on a persons lap who is sitting on a couch <end>',
#  "<start> A cat lays on its back while sitting in someone's lap. <end>",
#  "<start> A cat sits with his belly up in a person's lap. <end>",
#  '<start> A person sitting on a couch with a cat laying on its back. <end>',
#  '<start> A woman holding a remote control in her right hand. <end>',
#  '<start> A woman playing a video game indoors.  <end>',
#  '<start> A woman standing in a room holding a remote control. <end>',
#  '<start> A woman stands with a Wii remote in her hand. <end>',
#  '<start> a standing woman with a remote control in hand  <end>',
#  '<start> A fresh cheese and basil pizza on a white plate <end>',
#  '<start> A pizza sitting on a white plate next to a glass of water. <end>',
#  '<start> A pizza with basil leaves served on a plate <end>',
#  '<start> A small pizza with sits on a white plate. <end>',
#  '<start> a margherita pizza being served on a plate <end>',
#  '<start> A Los Angeles school bus parked in a parking lot. <end>',
#  '<start> A yellow bus is shown parked in a parking lot. <end>',
#  '<start> A yellow bus without passengers standing on the road. <end>',
#  '<start> An old yellow school bus is parked in a lot. <end>',
#  '<start> a yellow school bus parked in a parking lot <end>',
#  '<start> A dog is looking at someone in the room. <end>',
#  '<start> A dog standing next to a skateboard on a wall. <end>',
#  '<start> A dog standing on hard wood floors and next to a wall with his shadow. <end>',
#  '<start> A dog stands next to a skateboard leaned up against a wall. <end>',
#  '<start> Dog and skateboard in a room and shadow of dog and person on a wall. <end>',
#  '<start> A number of stuffed toy dogs set together. <end>',
#  '<start> Stuffed animals are hanging on poles in the air. <end>',
#  '<start> This  bear is a soft, furry prize children want to win a the summer carnival. <end>',
#  '<start> Toy Pomeranian dog on bag for playing with and enjoyment. <end>',
#  '<start> a white stuffed bear is in a room <end>',
#  '<start> A field covered in snow on top of a hillside. <end>',
#  '<start> A scenic view of a snow covered mountain and clouds. <end>',
#  '<start> A sign stands on a snowy kill under a cloudy sky. <end>',
#  '<start> Snow that is on a hill overlooking mountains. <end>',
#  '<start> Sun peeks through the cloudy on top of a snowy mountain. <end>',
#  '<start> A man holding his hands together while sitting on a bench. <end>',
#  '<start> A man sits on a bench with a man-made waterfall behind him.  <end>',
#  '<start> A man sitting on top of a brown bench in front of a fountain. <end>',
#  '<start> An old man sits on a park bench beside a fountain <end>',
#  '<start> Older man sitting on bench in front of water fountain <end>',
#  '<start> A bed is covered by a gold decorative cover.  <end>',
#  '<start> A very big and fancy looking room with a big pretty bed. <end>',
#  '<start> Old style bed has a cross on the headboard <end>',
#  '<start> This is bed in someones bedroom in their house.  <end>',
#  '<start> a bed room that is filled with ancient cloth like sheets  <end>',
#  '<start> A guy and a girl hugging on a dirt bike.  <end>',
#  '<start> A man riding a motorcycle with a beautiful woman on his lap. <end>',
#  '<start> A motorcyclist and a woman posing on a bike for a photo. <end>',
#  '<start> A rider sits on a dirt bike with a woman in his lap. <end>',
#  '<start> Man on dirt bike with a redheaded woman in his lap. <end>',
#  "<start> A group of people playing double's tennis outdoors <end>",
#  '<start> People playing tennis on the court on a sunny day <end>',
#  '<start> Two tennis courts both have doubles games playing on them. <end>',
#  '<start> Wide shot o group playing tennis on a court. <end>',
#  '<start> a group of people on a tennis court playing tennis  <end>',
#  '<start>  A man and two women disembark from two colorful busses. <end>',
#  '<start> A man standing next to a large red bus. <end>',
#  '<start> A man stands next to a red bus on the street <end>',
#  '<start> Man standing outside a red and black school bus. <end>',
#  '<start> Two people standing outside of a remodeled school bus <end>',
#  '<start> A JAL airplane taxiing down a runway in a city. <end>',
#  '<start> A large jetliner taking off from an airport runway. <end>',
#  '<start> An airplane on a bridge over a highway. <end>',
#  '<start> An airplane sitting in the middle of a city.  <end>',
#  '<start> Very large JAL jet taxiing on the runway at airport in urban environment <end>',
#  '<start> A group of people standing around an airplane. <end>',
#  "<start> Men are standing in front of a prop plane and one man is actually standing in the driver's area and holding on to the top wing. <end>",
#  '<start> People gather around as a man gets into an old-time airplane. <end>',
#  '<start> Several people standing around and looking at a vintage plane. <end>',
#  '<start> large group of people standing next to very old style air plane <end>',
#  '<start> A CGI bathroom with a oval tub filled with water. <end>',
#  '<start> A computer rendering of a bathroom shows stone walls and a large tub with a window. <end>',
#  '<start> The sink of a large modern bathroom is full of water. <end>',
#  '<start> This is a bathroom with a jacuzzi, shower, sink, and toilet. <end>',
#  '<start> a bathroom with a tub a toilet and a stand up shower <end>',
#  '<start> A glass of toothbrushes sitting on a counter <end>',
#  '<start> Three colored toothbrushes standing in a glass holder. <end>',
#  '<start> Three toothbrushes are in a clear glass cup. <end>',
#  '<start> Three toothbrushes sit inside of a glass on the counter. <end>',
#  '<start> an image of three toothbrushes in side a glass holder <end>',
#  "<start> A man leaning over as she inspects a woman's shoes. <end>",
#  '<start> Man standing in front of a woman next to a suitcase.  <end>',
#  '<start> a man kneeling down looking at a ladies shoes <end>',
#  '<start> a person standing and a person looking down <end>',
#  '<start> this is two men standing on some stairs <end>',
#  '<start> A cat is in the grass chewing on a shoestring.  <end>',
#  '<start> A cat playing with a shoe in a grassy field. <end>',
#  '<start> The cat is laying in the grass next to a shoe.  <end>',
#  '<start> a close up of a cat laying on grass near a shoe <end>',
#  '<start> an image of a cat that is playing with a shoe <end>',
#  '<start> A Chihuahua dog is standing next to a toy giraffe and looking up.  <end>',
#  '<start> A brown and white chihuahua stands over a stuffed giraffe toy and a gray ribbon. <end>',
#  '<start> The chihuahua is looking up at the wooden structure rather than at the moose on the ground. <end>',
#  '<start> The small dog is looking up at the camera. <end>',
#  '<start> there is a white and beige dog sitting on the floor <end>',
#  '<start> A close up picture of a meal on a white plate. <end>',
#  '<start> A cooked stir fry dish arranged on a plate. <end>',
#  '<start> A picture of a bowl of food that is mostly vegetables. <end>',
#  '<start> Food on a white plate with vegetables and a garnish. <end>',
#  '<start> a plate of yummy food of some kind <end>',
#  '<start> A television sitting in the middle of a river <end>',
#  '<start> A tv in the middle of a fast flowing river. <end>',
#  '<start> A tv sitting next to a river with a busted screen. <end>',
#  '<start> An old TV monitor sits in the middle of a stream. <end>',
#  '<start> There is an old TV in the middle of a swamp <end>',
#  '<start> A heard of elephants are walking through the field in a line. <end>',
#  '<start> A herd of elephants and their calves walking single file <end>',
#  '<start> A herd of elephants cross an exotic savanna. <end>',
#  '<start> A herd of elephants walking across a dry grass field. <end>',
#  '<start> Elephant herd, in a line, walking across savanna. <end>',
#  '<start> A cappuccino cup next to plates of deserts. <end>',
#  '<start> A cup of coffee on a plate with a spoon. <end>',
#  '<start> A cup of liquid with a fancy design on top of it. <end>',
#  '<start> Cup of coffee with dessert items on a wooden grained table. <end>',
#  '<start> Pastry, water and a cup of coffee with spoon. <end>',
#  '<start> A bunch of stuffed animals laying on a bed. <end>',
#  '<start> A group of teddy bears laying on top of a red bed. <end>',
#  '<start> Large group of stuffed animals sitting on top of a red bed.  <end>',
#  '<start> There is a canopy bed with red sheets, and a bunch of stuffed animal on it. there are two furry lamps on nightstands next to the bed. <end>',
#  '<start> a brightly decorated bedroom with assorted stuffed animals in the room  <end>',
#  '<start> Large cheese pizzas stacked in a warming oven. <end>',
#  '<start> Pans of dough sit atop racks holding pizzas.  <end>',
#  '<start> Three pans of pizza in a cart that holds pizzas.  <end>',
#  '<start> a couple of pizzas are sitting on racks <end>',
#  '<start> some large pizzas on trays and some orange floor tiles  <end>',
#  '<start> 3 people attempt to catch a frisbee in midair.  <end>',
#  '<start> A group of woman standing in a field trying to catch a frisbee <end>',
#  '<start> Three girls playing frisbee together in a field. <end>',
#  '<start> Three young women are trying to catch a frisbee. <end>',
#  '<start> three people in a grass field reaching for a frisbee in the air <end>',
#  '<start> A close up of a motorcycle parked on the sidewalk next to a door. <end>',
#  '<start> A motorcycle parked on the side of a building with mural <end>',
#  '<start> An old motorcycle parked outside a rustic building. <end>',
#  "<start> An old motorcycle rests on it's kickstand by a door, in front of a wall with a mural of a tree. <end>",
#  '<start> Rusted red motorcycle parked beside a red building.  <end>',
#  '<start> A kid on a skate board riding on a ramp. <end>',
#  '<start> A man riding a skateboard on a ramp. <end>',
#  '<start> A person standing on a skateboard and skating at a park. <end>',
#  '<start> A teenager riding a skateboard at a skate park. <end>',
#  '<start> A young man riding a skateboard down a ramp. <end>',
#  '<start> A computer desk with a desktop computer and a stuffed turtle on top.  <end>',
#  '<start> A computer is on a desk along with several knickknacks. <end>',
#  '<start> A desktop computer and monitor on a  desk. <end>',
#  '<start> A desktop computer with a stuffed animal turtle on top. <end>',
#  '<start> There is a stuffed turtle on the computer monitor.  <end>',
#  '<start> A cat sitting on top of a car near bushes. <end>',
#  '<start> A curious looking cat sitting on a car. <end>',
#  '<start> Cat sitting on top of car with brush behind.  <end>',
#  '<start> a black gray and white cat a car and bushes <end>',
#  '<start> a cat is sitting on top of a vehicle <end>',
#  '<start> A gold and black motorcycle is parked by some grass. <end>',
#  '<start> A gold motorcycle parked in parking lot next to a building. <end>',
#  '<start> A motorcycle parked in a parking space in front of a store. <end>',
#  '<start> A motorcycle parked in a parking spot in a lot. <end>',
#  '<start> there is a orange and black motorcycle that is parked  <end>',
#  '<start> A train engine carrying carts parked at a station. <end>',
#  '<start> A train with googly eyes sitting near a platform. <end>',
#  '<start> Train with bright striped rear with attendants and onlookers on platform. <end>',
#  '<start> a yellow and black stripped train next to sidewalk <end>',
#  '<start> there is a train that is stopped at the station <end>',
#  '<start> A bunch of boxes full of assorted fruit on display. <end>',
#  '<start> A display of boxes with several types of fruits. <end>',
#  '<start> A fruit and produce stand with food being displayed in produce boxes.   <end>',
#  '<start> Apples, oranges and other fruit displayed for sale in boxes <end>',
#  '<start> Boxes of fresh fruit on display in a market. <end>',
#  '<start> A statue of a man on a horse and a group of trees with no leaves behind it.  <end>',
#  '<start> A statue of a man on top of a horse. <end>',
#  '<start> A statue of a roman soldier sitting on a horse. <end>',
#  '<start> A statue of a soldier sitting atop a horse <end>',
#  '<start> Statue of man with cape on horse in front of trees and building. <end>',
#  '<start> A big empty beach with a bunch of surf boards. <end>',
#  '<start> A sandy beach covered in white surfboards near the ocean. <end>',
#  '<start> Eleven surfboards face down on an empty beach. <end>',
#  '<start> Many surfboards laying in the sand at the beach. <end>',
#  '<start> surfboards sitting on the sand of a beach <end>',
#  '<start> A large long white bus on a road. <end>',
#  '<start> A red and white bus driving down the side of a road. <end>',
#  '<start> A white and red bus on side of street. <end>',
#  '<start> Passenger bus parked on street with sunset in background <end>',
#  '<start> The bus is parked on the quiet road waiting for its passengers. <end>',
#  '<start> A three piece circular mirror with a girl taking a picture of it in the reflection <end>',
#  '<start> A woman and a cat reflected in a mirror made of three circular sections <end>',
#  '<start> A woman is taking a picture looking into a mirror while the cat watches. <end>',
#  '<start> A woman that is with a cat in a mirror. <end>',
#  '<start> a woman taking a selfie in front of a stack of mirrors <end>',
#  '<start> A man on a motorcycle is going down the street. <end>',
#  '<start> A man riding a motorcycle next to a lush green forest. <end>',
#  '<start> A motorcyclist travels down a country two-lane highway. <end>',
#  '<start> A person is riding a motorcycle down a country road. <end>',
#  '<start> a person riding a motorcycle on a road with trees <end>',
#  '<start> A giraffe standing alone next to a tree. <end>',
#  '<start> A giraffe standing in a stand of trees.  <end>',
#  '<start> A single giraffe stand among some busy trees. <end>',
#  '<start> The giraffe stands alone in very tall brush. <end>',
#  '<start> a giraffe standing in front of a tree  <end>',
#  '<start> A bathroom is made over and painted and decorated <end>',
#  '<start> A set of two pictures of two toilets in a bathroom. <end>',
#  '<start> Two bathrooms with different decor on each of them <end>',
#  '<start> Two different bathrooms, one has a green toilet <end>',
#  '<start> a split photo with some toilets inside of it  <end>',
#  '<start> A group of people that are sitting in front of laptops. <end>',
#  '<start> People are sitting in the dark using computers.  <end>',
#  '<start> The extra laptop is on standby for the computer users. <end>',
#  '<start> The people are using their computers in the dark.  <end>',
#  '<start> a dark room with three people on computers <end>',
#  '<start> Clowns are bowing to each other at an air show. <end>',
#  '<start> Clowns are on hand to assist fliers with their kites. <end>',
#  '<start> People are gathering near bright orange air balloons. <end>',
#  '<start> Some colorful kits being flown on a field during the day. <end>',
#  '<start> a group of people in a field flying large floats  <end>',
#  '<start> A bar and cafe with a motorcycle parked out front. <end>',
#  '<start> A large motorcycle sits outside of a bar. <end>',
#  '<start> A motorcycle is parked in front of a cafe. <end>',
#  '<start> A motorcycle is parked outside of a cafe. <end>',
#  '<start> a motorcycle parked in front of a small cafe <end>',
#  '<start> A lady stands in a flooded grassy spot surrounded by tents. <end>',
#  '<start> A woman holding her umbrella is standing in a quite large puddle.  <end>',
#  '<start> A woman under and umbrella standing in water on a flooded field with tents in the background. <end>',
#  '<start> A woman wearing a pink hat holding a black umbrella. <end>',
#  '<start> Female camper standing ankle deep in water under an umbrella <end>',
#  '<start> A woman cuts a large cake that has a lit candle. <end>',
#  '<start> A woman has her picture taken while she cuts a cake. <end>',
#  '<start> A woman with a knife cutting into a cake. <end>',
#  '<start> A women cutting a large cake with one lit candle. <end>',
#  '<start> a woman cutting into a big birthday cake with one candle <end>',
#  '<start> A giraffe in a field staring at the camera. <end>',
#  '<start> A giraffe is turning its head to look at the photographer <end>',
#  '<start> A giraffe standing and posing in a prairie setting. <end>',
#  '<start> The giraffe is standing alone in the wilderness. <end>',
#  '<start> a giraffe standing in tall grass with trees in the background <end>',
#  '<start> A bathroom has a bottle of cleaning wipes. <end>',
#  '<start> A small bathroom with a glass shower door, sink, toilet, and disinfecting wipes. <end>',
#  '<start> A small bathroom with a mirror, shower, toilet and vanity. <end>',
#  '<start> A toilet with sink, sanitizers  and a mirror <end>',
#  '<start> A yellow Clorox wipe dispenser sitting on a bathroom sink. <end>',
#  '<start> A living room filled with furniture on top of a hard wood floor. <end>',
#  '<start> A very big nice looking room with a bright window. <end>',
#  '<start> Living room with wood floor TV couches and chair. <end>',
#  '<start> a living room filled with couches chairs and a water cooler sitting on a hard wood floor <end>',
#  '<start> a living room with big couches and a ceiling fan  <end>',
#  '<start> A man riding water skis on top of a body of water. <end>',
#  '<start> A para sailer leans back and pulls on the rope connected to his sail.  <end>',
#  '<start> A person that is wind surfing in the water. <end>',
#  '<start> The kite surfer is spraying up water as he surfs. <end>',
#  '<start> While a purple/blue sky with what looks like a kite or a loose para-sail floating in it covers most of a distance shot, the bottommost part shows grassy side banks and a body of water with a water skier being pulled. <end>',
#  '<start> A group of people are gathered around a table with cake on it.  <end>',
#  '<start> Four persons sitting on dining table for cake and drinks.  <end>',
#  '<start> Group around a table waiting for a birthday cake to be served. <end>',
#  '<start> a family is sitting down at a table to have cake <end>',
#  '<start> adults at dining room table with birthday cake. <end>',
#  '<start> A COUPLE OF PEOPLE JUST GETTING OFF OF A TRAIN \n <end>',
#  '<start> A train passing through a station  on the middle track. <end>',
#  '<start> A yellow train pulling into the train platform filled with people <end>',
#  '<start> Many people are walking with suitcases in a train station. <end>',
#  '<start> Passengers are walking alongside a yellow train inside of a station <end>',
#  '<start> A couple of elephants being playful with each other. <end>',
#  '<start> Two elephants are play fighting each other in a field. <end>',
#  '<start> Two elephants being playful or aggressive with their trunks. <end>',
#  '<start> Two elephants facing each other and one is touching the other with its trunk <end>',
#  '<start> Two very big elephants playing together in a field. <end>',
#  '<start> A very large clock tower on the side of a church. <end>',
#  '<start> An old building has a clock tower with a weather vane. <end>',
#  '<start> An old building with a clock at the top of it. <end>',
#  "<start> An old building's clock tower is being displayed. <end>",
#  '<start> The tall clock tower is built into the corner edge of the building. <end>',
#  '<start> A flock of ducks floating on top of a lake. <end>',
#  '<start> The three ducks are by the water outside. <end>',
#  '<start> Three ducks walking along a dock near the water. <end>',
#  '<start> Three geese that are standing by a pond. <end>',
#  '<start> three ducks next to the shore of a pond <end>',
#  '<start> A black and white photograph of two men on side of the road. <end>',
#  '<start> Two men by a church and a parking lot. <end>',
#  '<start> Two men outside near a car and moving a cart of some sort. <end>',
#  '<start> Two men standing near each other by some parked cars <end>',
#  '<start> an old black and white photo of two people <end>',
#  '<start> A cat sleeping on a bed next to a comforter. <end>',
#  '<start> A white cat sleeping on a bed in the sun <end>',
#  '<start> Black and white photograph of a cat snoozing on a bed <end>',
#  '<start> Cat Siamese looking sleeping on its side on a comforter. <end>',
#  '<start> a white cat lying on the bed sleeping <end>',
#  '<start> A man in a cap on a surf board and holding an oar.  <end>',
#  '<start> A man on a surfboard in the water. <end>',
#  '<start> A man stands on a surf board and holds a paddle. <end>',
#  '<start> A man with a paddle riding a wave on a surfboard. <end>',
#  '<start> Guy in a cap is paddle surfing on a wave <end>',
#  '<start> A couple of men playing frisbee against each other on a field. <end>',
#  '<start> Two teenagers playing of game of Frisbee in a field. <end>',
#  '<start> Two young men play with a Frisbee in a grassy area. <end>',
#  '<start> Two young men playing frisbee in a park. <end>',
#  '<start> this is two men in cleats on the grass <end>',
#  '<start> A bowl full of tuna salad next to two slices of bread topped with the salad and one with ketchup on it. <end>',
#  '<start> A sandwich covered in red sac use and chicken salad. <end>',
#  '<start> The sandwich bread is being covered with sauce and salad. <end>',
#  '<start> Two pieces of bread with sauce on them next to a bowl of chicken salad.  <end>',
#  '<start> an image of a chicken salad sandwich being made <end>',
#  '<start> A dog and his owner on the back of a boat. <end>',
#  '<start> A man holding a puppy on a boat. <end>',
#  '<start> A man holding his dog while on a boat. <end>',
#  '<start> A man on a boat holding his dog in his lap. <end>',
#  '<start> A man riding on a boat on the ocean while holding an adorable bull dog. <end>',
#  '<start> A person laying on the ground  on a pair of skis.  <end>',
#  '<start> A skier that has fallen in the snow  <end>',
#  '<start> A young man laying on the ground while wearing skis. <end>',
#  '<start> Skier in blue jacket laying down in the snow on their stomach.  <end>',
#  '<start> a person on the ground wearing skis  <end>',
#  '<start> A busy city street lit up at night in a foreign country. <end>',
#  '<start> A city street has lighted signs and buildings. <end>',
#  '<start> A city street with many tall lighted buildings. <end>',
#  '<start> A downtown city street at night with neon signs. <end>',
#  '<start> A street at night with people walking around and buildings lit up. <end>',
#  '<start> A bowl filled with fruit on top of a table. <end>',
#  '<start> A bowl of exotic fruit is in a bowl on the table. <end>',
#  '<start> A bowl of fruit is sitting on top of the table. <end>',
#  '<start> A bowl sits on a table, containing bananas and other food. <end>',
#  '<start> Fruit in ceramic bowl on wood table with white walls <end>',
#  '<start> A frame is attached to a wall near a kitchen. <end>',
#  '<start> A home kitchen with posters from Nashville, Tennessee <end>',
#  '<start> A kitchen with art and a menu hanging on the wall <end>',
#  '<start> A kitchen with signs on the wall outside of it. <end>',
#  '<start> The interior decor in an average kitchen.  <end>',
#  '<start> A computer is on a desk next to a mess. <end>',
#  '<start> A computer sitting on a desk with candy and drinks by it. <end>',
#  '<start> A computer with an empty bottle, cup and box of crackers beside it. <end>',
#  '<start> A desk with a computer monitor and a keyboard. <end>',
#  '<start> Crackers, Starburst, and a bottle of water are on a desk next to a computer. <end>',
#  '<start> A airplane that is sitting on a runway. <end>',
#  '<start> A jet sits on display in during an air show. <end>',
#  '<start> Jet plane on tarmac with people and cloudy sky <end>',
#  '<start> Several airplanes sitting on the tarmac at an airport. <end>',
#  '<start> Two jets sit on the tarmac on a sunny day.  <end>',
#  '<start> A man holding his hands near his balls and wearing a watch. <end>',
#  '<start> A man in a suit and tie sitting with his hands between his legs. <end>',
#  '<start> There is a man with his hands in his lap <end>',
#  '<start> a man from the neck down with a suit and tie on <end>',
#  '<start> there is a man sitting on the train wearing a suit <end>',
#  '<start> A black and white photo of a little girl on a skate board. <end>',
#  '<start> A little kid that is on a skateboard. <end>',
#  '<start> A young girl riding a skateboard across school yard. <end>',
#  '<start> A young girl wearing a helmet skates on a skateboard. <end>',
#  '<start> Black and white photograph of a happy girl skateboarding <end>',
#  '<start> People stand by watching a couple elephants taking a nice walk together <end>',
#  '<start> Two elephants in a zoo grazing on leaves. <end>',
#  '<start> Two very big elephants standing together in an enclosure. <end>',
#  '<start> two elephants on a dirt ground near tres <end>',
#  '<start> two elephants standing next to each other on a dirt ground next to trees. <end>',
#  '<start> A bed with a book, black laptop and blanket. <end>',
#  '<start> A book sitting open and on top of a table. <end>',
#  '<start> An open book beside a computer and some clothing. <end>',
#  '<start> An open book next to a laptop setting on a bed <end>',
#  '<start> a close up of a book near a laptop on a bed <end>',
#  '<start> A doghouse and dogs sculpted from sand with a toy fire hydrant. <end>',
#  '<start> A red fire hydrant and a sand sculpture on a beach. <end>',
#  '<start> Doghouse and cat made from sand by a toy fire hydrant. <end>',
#  '<start> Someone on the beach has built a sand doghouse. <end>',
#  '<start> people built a dog house shaped sand castle <end>',
#  '<start> A display filled with luggage and a poster. <end>',
#  '<start> A display of Australia trunks in various sizes <end>',
#  '<start> A display of suite cases behind glass with a poster for Australia in the background.  <end>',
#  '<start> A display setting with a bunch of luggage on a shelf. <end>',
#  '<start> a couple of trunks are in a glass case <end>',
#  '<start> A woman with a beer is wearing a gray tie. <end>',
#  '<start> a girl is wearing a tie and a dress <end>',
#  '<start> a woman wearing a tie holding onto an almost empty beer  <end>',
#  '<start> there is a woman holding a beer and dancing <end>',
#  '<start> this woman is drinking a beer and dancing <end>',
#  "<start> A person's legs in the snow wearing a snowboard. <end>",
#  '<start> A persons legs on a snowboard in the snow. <end>',
#  '<start> A snowboarder laying down to show his legs and feet on the snowboard. <end>',
#  '<start> A snowboarder resting by sitting down in the snow. <end>',
#  '<start> a snowboarder in blue pants standing on his snowboard <end>',
#  '<start> A cat lying on a couch with pillows <end>',
#  '<start> A couple of cats laying on a couch in a room. <end>',
#  '<start> There are three cats laying on a couch. <end>',
#  '<start> Three cats are stretched out on a couch. <end>',
#  '<start> a couple of kitty cats sprawled out on a sofa <end>',
#  '<start> A Minnie the Mouse cake sits on a cutting board. <end>',
#  '<start> A cake decorated to look like a female mouse. <end>',
#  '<start> A cake of a animated character, with a bow on its head. <end>',
#  '<start> The face of a dog with its tongue sticking out.  <end>',
#  '<start> a close up of a cake made to look like minnie mouse  <end>',
#  '<start> A pair of hands split a bundle of bananas on top of a box of oranges. <end>',
#  '<start> A person is holding a small bushel of bananas. <end>',
#  '<start> A person pulling apart a bunch of bananas in a box. <end>',
#  "<start> A person pulling apart a bundle of banana's in a crate. <end>",
#  '<start> A person selecting some bananas from a bunch. <end>',
#  '<start> A couple of giraffe in a fenced in area. <end>',
#  '<start> Some giraffes hanging out together in a fenced area. <end>',
#  '<start> Two giraffes are standing in an enclosed area. <end>',
#  '<start> Two giraffes standing next to each other in a zoo. <end>',
#  '<start> Two giraffes, one adult, one young walk in a fenced area as another lays on the ground. <end>',
#  '<start> A man in slippers standing on the side of the street talking on a cell phone. <end>',
#  '<start> A man standing on the sidewalk in his underwear wearing animal slippers. <end>',
#  '<start> A man wearing a leather jacket, shorts and oversized slippers. <end>',
#  '<start> MAN ON CELL PHONE STANDING ON STREET CORNER IN HOUSE SLIPPERS <end>',
#  '<start> a person stading on a city street in shorts and slippers  <end>',
#  '<start> A street with people carrying their bags and suitcases  <end>',
#  '<start> An overhead view of several people walking down a street carrying luggage. <end>',
# ...
#  '<start> A living room with a view of the dining room <end>',
#  '<start> A sea with many boats anchored at the bay <end>',
#  '<start> An orange boat docked next to a platform. <end>',
#  '<start> Several boats parked in a large body of water. <end>',
#  '<start> Some old boats on some water sitting at a dock. <end>',
#  '<start> The marina at a lake or ocean  <end>',
#  '<start> A model red plane hung from a ceiling. <end>',
#  '<start> A plane that is hanging up in the air. <end>',
#  '<start> A red airplane is hanging from the ceiling. <end>',
#  '<start> A red and white Airplane hanging from a ceiling. <end>',
#  '<start> There is a red plane hanging from the ceiling. <end>',
#  '<start> A guy playing with a Frisbee outside during the daytime. <end>',
#  '<start> A man in a park has just thrown a frisbee. <end>',
#  '<start> A man stands as a frisbee flies through the air. <end>',
#  '<start> A man throwing a frisbee in a green field. <end>',
#  '<start> Man throwing a red Frisbee in a park. <end>',
#  '<start> People are standing in the sand on the beach flying a kite. <end>',
#  '<start> People with a parasail on a smooth beach. <end>',
#  '<start> Three people on a beach fly a kite above them <end>',
#  '<start> Three people on a beach flying a large kite. <end>',
#  '<start> Three people on a beach one is flying a kite. <end>',
#  '<start> A man dressed in a homemade costume wields a baseball bat and grimaces.  <end>',
#  '<start> A man holding a baseball bat while standing in an airport. <end>',
#  '<start> A man in a funny costume poses for a picture. <end>',
#  '<start> A mustachioed man in football pads and helmet poses aggressively with a baseball bat in his hand.   <end>',
#  '<start> a man dressed up in a goofy costume <end>',
#  '<start> A bathroom with a toilet, sink and a window in it.  <end>',
#  '<start> A bathroom with toilet, sink, window with curtain, painted wood walls, and half wood and half concrete floor. <end>',
#  '<start> A very small, beat up bathroom in an older building. <end>',
#  '<start> An old looking bathroom, just a toilet and sink.  <end>',
#  '<start> This restroom has a toilet, a window and a sink. <end>',
#  '<start> A bridge in a city park with flowers growing all around it.  <end>',
#  '<start> A person is walking in the rain by some flowers. <end>',
#  '<start> A person walking on a path with an orange umbrella. <end>',
#  '<start> A person with an umbrella walking near the flowers. <end>',
#  '<start> A women who is walking down a sidewalk with an umbrella.  <end>',
#  '<start> A couple of giraffe standing next to a tall building. <end>',
#  '<start> Giraffes come to the hay dispenser for a quick snack. <end>',
#  '<start> The two giraffes are enjoying their meal together.. <end>',
#  '<start> Two giraffes eating hay out of a raised feeder. <end>',
#  '<start> two giraffes eating feed out of a bin  <end>',
#  '<start> A man hanging from a ladder attached to a flying small plane with a man on a motorcycle beneath him. <end>',
#  '<start> A person on a ladder hanging from a plane over a motorcycle. <end>',
#  '<start> A stuntman on a rope ladder suspended from a plane in motion with a motorcycle traveling underneath. <end>',
#  '<start> An airplane flying through the air over a motorcycle. <end>',
#  '<start> There is an exchange of passenger between the airplane and the motorcycle via the rope ladder. <end>',
#  '<start> A person that is holding a teddy bear while sitting down. <end>',
#  '<start> A woman in a wheelchair holding onto a teddy bear. <end>',
#  '<start> An elderly woman in a wheelchair opening  Christmas gifts <end>',
#  '<start> An elderly woman in a wheelchair poses with a large stuffed bear. <end>',
#  '<start> An older woman sitting in a wheel chair holding a big white teddy bear. <end>',
#  '<start> A herd of elephants walking in the grazing field <end>',
#  '<start> A herd of elephants with large and small elephants at the zoo. <end>',
#  '<start> A young elephant huddled between a group of adult elephants <end>',
#  '<start> THIS IS A PICTURE OF A LARGE FAMILY OF ELEPHANTS <end>',
#  '<start> a group of elephants standing around eating grass <end>',
#  '<start> A breakfast of porridge, fruit and a quick bread. <end>',
#  '<start> A table with baked bread,sliced fruit and a congealed salad. <end>',
#  '<start> Plates of food that include different types of desserts. <end>',
#  '<start> There is a bowl of food with bread and a plate of fruit. <end>',
#  '<start> Two plates and a bowl full of food sitting on a table. <end>',
#  '<start> A table topped with personal items and electronics. <end>',
#  '<start> Assortment of traveling items displayed on wooden table. <end>',
#  '<start> Many cosmetic items are arranged next to a map. <end>',
#  "<start> Several items are displayed that might commonly be found in a woman's purse. <end>",
#  '<start> Several items on a table for going on a hike or camping  <end>',
#  '<start> A group of men in a kitchen doing installations.  <end>',
#  '<start> A group of men standing around a counter in a kitchen. <end>',
#  '<start> Five men in a kitchen, two sitting on a counter and one with a beer in his hand. <end>',
#  '<start> Five people in a house, one holding a bottle <end>',
#  '<start> a group of people trying to hook up an appliance  <end>',
#  '<start> A giraffe stands and puts a tree branch in its mouth. <end>',
#  '<start> A giraffe trying to eat leaves on the top of a branch <end>',
#  '<start> Giraffe eating off a tree branch on an open field.  <end>',
#  '<start> a giraffe nibbling on a branch of a tree <end>',
#  '<start> a griffa trying to eat leaves that has already been ate <end>',
#  '<start> A European city square with a clock tower.  <end>',
#  '<start> A big wide street near a tall tower with a clock. <end>',
#  '<start> A large building with a clock and people nearby. <end>',
#  '<start> A large clock tower towering over a small city. <end>',
#  '<start> A picture of an old clock tower downtown. <end>',
#  '<start> A man cutting food with a pair of blue scissors.  <end>',
#  '<start> A man sitting with his back up against a tree. <end>',
#  "<start> It's good to take off your shoes and relax in the sun for lunch. <end>",
#  '<start> The man is enjoying a snack at the park. <end>',
#  '<start> a man is sitting on the grass eating some food and a drink <end>',
#  '<start> A kitchen is shown with a tv mounted on the wall. <end>',
#  '<start> A living room with a wall mounted TV next to a table. <end>',
#  '<start> The view of a dining room and bar area in a home. <end>',
#  '<start> View from the living room into the dining room of a house <end>',
#  '<start> a table with chairs a counter with stools with large windows <end>',
#  '<start> A person holding a tray containing carrots near a vehicle. <end>',
#  '<start> A person holding a tray full of orange carrots. <end>',
#  '<start> A woman carries a tray of carrots down a street. <end>',
#  '<start> A woman in a colorful dress carrying a tray of carrots on a dirt road. <end>',
#  '<start> A woman is carrying carrots by a truck <end>',
#  '<start> A fit young man surfing a wave in the ocean. <end>',
#  '<start> A man in swim shorts is riding a surf board. <end>',
#  '<start> A man riding a surfboard on a wave. <end>',
#  '<start> A shirtless man riding shortboard on a wave. <end>',
#  '<start> A surfer is riding a wave in the ocean. <end>',
#  '<start> A commercial airplane with the door open and people walking in. <end>',
#  '<start> A delta  connection passenger plane ready to board. <end>',
#  '<start> A large jet sitting on top of an airport runway. <end>',
#  '<start> THERE IS A DELTA CONNECTION PLATE THAT IS PARKED ON THE YARD <end>',
#  '<start> there are people boarding a very large plane <end>',
#  '<start> A beautiful young woman riding on the back of a motorcycle. <end>',
#  '<start> A woman sitting on a moped in the street <end>',
#  '<start> Someone is doing something that is quite fun. <end>',
#  '<start> Woman on a motorized scooter driving down a narrow street. <end>',
#  '<start> a woman in a white helmet parked by a curb <end>',
#  '<start> A big cat and a small cat sitting down with their backs turned <end>',
#  '<start> A cat and and a kitten watch television together. <end>',
#  '<start> Pair of cats sitting on table watching television together. <end>',
#  '<start> Two cats sit side by side while looking at a television. <end>',
#  '<start> a couple of cats that are in front of a t.v. <end>',
#  '<start> A cat sands proudly and full of valor a top a horse <end>',
#  '<start> A cat standing on top of a black horse.  <end>',
#  '<start> An orange cat standing on the back of a dark horse. <end>',
#  '<start> An orange cat standing on the top of a brown horse. <end>',
#  '<start> a cat stands on top of a horse  <end>',
#  '<start> A disc golfer releases a throw from a dirt tee box on a wooded course. <end>',
#  '<start> A partially black and white photo of a man throwing something into the woods. <end>',
#  '<start> The person is in the clearing of a wooded area.  <end>',
#  '<start> a person throwing a frisbee at many trees  <end>',
#  '<start> a young guy walking in a forrest holding an object in his hand <end>',
#  '<start> A man on a horse without a saddle stands on a hill. <end>',
#  '<start> A man riding on the back of a horse. <end>',
#  '<start> A man sitting on a horse on a hill  <end>',
#  '<start> A person sitting on a horse on top of a grassy hill.  <end>',
#  '<start> an Indian riding a black and white horse bareback  <end>',
#  '<start> A large airplane flying on top of a grass covered field. <end>',
#  '<start> An old picture of a airplane on the ground  <end>',
#  '<start> Or large airplane crashed into a field on the grass.  <end>',
#  "<start> People stand around an old airplane that is tilted on it's nose. <end>",
#  '<start> There is a crashed plane in the field. <end>',
#  '<start> A kitchen with a center island and a metallic refrigerator. <end>',
#  '<start> A tidy and clean kitchen with counter burners <end>',
#  '<start> A well lit kitchen with an island and stainless steel refrigerator <end>',
#  '<start> a kitchen with a center isle stove, and stainless steel refrigerator. <end>',
#  '<start> an image of a kitchen setting with stainless steel appliances <end>',
#  '<start> A man flies a kite against a blue sky. <end>',
#  '<start> A man flying a kite in a cloudy blue sky. <end>',
#  '<start> A man flying a kite in the mountains. <end>',
#  '<start> A man flying a kite up in the air. <end>',
#  '<start> A man is holding on to a powerful kite. <end>',
#  '<start> A baby with a Santa hat on and boots hold a pair of pliers. <end>',
#  '<start> A little boy that is standing near a counter. <end>',
#  '<start> A young boy wearing a diaper and a Santa hat in a kitchen. <end>',
#  '<start> a boy in a santa hat holding a pair of nutcrackers in a kitchen  <end>',
#  '<start> a child in a kitchen on a step ladder  <end>',
#  '<start> A large building that has a clock tower. <end>',
#  '<start> A wide panned shot of London at daytime. <end>',
#  '<start> The building in the city was very large. <end>',
#  '<start> a big building that has some towers with a clock at the top <end>',
#  '<start> a building with a large clock tower on it <end>',
#  '<start> A person hitting a ball on a tennis court. <end>',
#  '<start> A tennis player swings her tennis racquet on the court. <end>',
#  '<start> A woman in the middle of swinging a tennis racket.  <end>',
#  '<start> The tennis player in a pink shirt is extending her racket.  <end>',
#  '<start> a women that has a tennis racket in her hand <end>',
#  '<start> A driver can easily herd sheep with a quad. <end>',
#  '<start> A large herd of animals walking in front of a person on a vehicle. <end>',
#  '<start> A man on a four wheeler trails a herd of sheep. <end>',
#  '<start> A person drives a herd of sheep using a four-wheeler. <end>',
#  '<start> A person on a four-wheeler herding sheep in the snow.  <end>',
#  '<start> A black tray holding a basket of fries and a sandwich. <end>',
#  '<start> A tray has a sandwich, french fries, and a drink on it. <end>',
#  '<start> A tray of food including a sandwich, fries and a drink <end>',
#  '<start> Meal consisting of a sub,fries and pepsi on a tray. <end>',
#  '<start> Sub sandwich with a side of waffle fries and a soft drink. <end>',
#  '<start> A small kid is learning to ski on the snow <end>',
#  '<start> A young child and two adults go skiing. <end>',
#  '<start> Two adults and a child on skis in the snow. <end>',
#  '<start> Two people on skis holding poles in the snow. <end>',
#  '<start> someone that is skiing across some white snow <end>',
#  '<start> A large metallic modern looking refrigerator sitting in a kitchen. <end>',
#  '<start> A silver colored refrigeration unit, in a kitchen. <end>',
#  '<start> A silver refrigerator is prominent in the kitchen. <end>',
#  '<start> A tall, skinny refrigerator in the corner of a kitchen.   <end>',
#  '<start> The silver cabinet does not match the rest of the room. <end>',
#  '<start> A man is riding on a surfboard in the ocean. <end>',
#  '<start> A man is surfing with his yellow and black striped surfboard <end>',
#  '<start> A young man riding a surf board on a small wave. <end>',
#  '<start> a man riding a colorful surfboard in the water <end>',
#  '<start> a person riding a surf board on a wave  <end>',
#  '<start> A blender sitting on top of a wooden floor. <end>',
#  '<start> A silver and clear drink container with a black tray of fruit next to it. <end>',
#  '<start> A small blender with a bowl of fruit next to it <end>',
#  '<start> An old fashioned type of blender in front of an old sign. <end>',
#  '<start> Two fruits sit in a bowl beside a blender. <end>',
#  '<start> A man holding a bottle is boating on a lake. <end>',
#  '<start> A man in a blue hat on a small boat. <end>',
#  '<start> A man is sitting in a boat on a river and drinking a bottle of water. <end>',
#  '<start> A man siting on top of a boat on top of a lake. <end>',
#  '<start> A man that is sitting in a boat wearing a hat. <end>',
#  '<start> A man that is holding a racquet standing in the grass. <end>',
#  '<start> A person on a court with a tennis racket. <end>',
#  '<start> A tennis player hits the ball during a match. <end>',
#  '<start> Man in white playing tennis on a court. <end>',
#  '<start> The tennis player is poised to serve a ball. <end>',
#  '<start> 2 airplanes are seen on the airport tarmac <end>',
#  '<start> A china airlines jet sitting on top of an airport tarmac. <end>',
#  '<start> A large airplane in a stationary position in the open. <end>',
#  '<start> A large commercial airplane parked on a runway <end>',
#  '<start> Two large jumbo jets are on the airport runway. <end>',
#  '<start> A group of girls waiting to be served cake. <end>',
#  '<start> A group of kids and a couple adults at a table with a three layered birthday cake. <end>',
#  '<start> A picture of some family having a birthday party.  <end>',
#  '<start> Several people around a table getting ready to cut into a cake. <end>',
#  '<start> little girls sitting at a table with a birthday cake in the middle  <end>',
#  '<start> A boy on a skateboard in the skate park  <end>',
#  '<start> A kid on a skate board at the top of a ramp. <end>',
#  '<start> A young man is riding a skateboard on a ramp. <end>',
#  '<start> A young man riding a skateboard up the side of a ramp. <end>',
#  '<start> a skateboarder doing tricks at a skating park  <end>',
#  '<start> A heard of cows stands in front of a man with a tractor. <end>',
#  '<start> A herd of cows standing on a grass covered field. <end>',
#  '<start> A herd of skinny cows are grazing on the grass. <end>',
#  '<start> Group of cows in a field with a man in the background. <end>',
#  '<start> a number of cows in a field with a person behind them <end>',
#  '<start> A GROUP OF PEOPLE ON SMALL FISHING BOATS LOOKING AT A FIERY COMING TOWARDS THEM <end>',
#  '<start> A boat of women are pushing off of the shore. <end>',
#  '<start> A couple of boats are on a a river <end>',
#  '<start> A few people are on small boats in a channel. <end>',
#  '<start> Two rowboats parked on the side of a small river with people in each of the boats. <end>',
#  ...]

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer(oov_token="<unk>", filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(annotation_list_train)

# %%
# Recorver the word index that was created with the tokenizer
word_index = tokenizer.word_index
word_count = tokenizer.word_counts

sorted_wc = sorted(word_count, key=word_count.get)

print('Found {} unique tokens.\n'.format(len(word_index)))

print("Show the most frequent word index:")
for i, word in enumerate(sorted_wc[::-1]):
    wi = word_index[word]
    wc = word_count[word]
    print('   {} ({}) --> {}'.format(word, wc, wi))
    if i == 20: 
        print('')
        break

print("Show the least frequent word index:")
for i, word in enumerate(sorted_wc):
    wi = word_index[word]
    wc = word_count[word]
    print('   {} ({}) --> {}'.format(word, wc, wi))
    if i == 20: 
        print('')
        break

# %%
#Trim by number of appearances
trimming_point = 1

trimmed_count = 0
trimmed_words = 0
for word in sorted_wc:
    wc = word_count[word]
    trimmed_count += wc
    trimmed_words +=1
    
    if wc > trimming_point:
        break
trimmed_words_appear_less = trimmed_words
trimmed_words_appear_less
# Out:
# 10586

# %%
#Trim by appearance distribution proportion
trim_proportion = 0.01

total_wc = sum(tokenizer.word_counts.values())

to_trim = trim_proportion*total_wc
trimmed_count = 0
trimmed_words = 0

for word in sorted_wc:
    wc = word_count[word]
    trimmed_count += wc
    trimmed_words +=1
    
    if trimmed_count > to_trim:
        break
    
trimmed_words_proportional = trimmed_words
trimmed_words_proportional
# Out:
# 21130

# %%
trimmed_words = trimmed_words_proportional

# %%
vocab_size = len(word_index) - trimmed_words
tokenizer = tf.keras.preprocessing.text.Tokenizer(num_words=vocab_size,oov_token="<unk>", filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n')
tokenizer.fit_on_texts(annotation_list_train)

# %%
embedding_count = vocab_size+1

# %%
annotation_lens_train = [ len(ann.split()) for ann in annotation_list_train]
max_window = max(annotation_lens_train)
max_window
# Out:
# 52

# %%
capt_train = tokenizer.texts_to_sequences(annotation_list_train)
capt_train = tf.keras.preprocessing.sequence.pad_sequences(capt_train,maxlen=max_window)
capt_train
# Out:
# array([[   0,    0,    0, ...,  192,   62,    4],
#        [   0,    0,    0, ...,  505, 1080,    4],
#        [   0,    0,    0, ...,   10,  437,    4],
#        ...,
#        [   0,    0,    0, ...,   66,   36,    4],
#        [   0,    0,    0, ...,   66,   36,    4],
#        [   0,    0,    0, ...,  214,   36,    4]], dtype=int32)

# %%
capt_train2 = capt_train[:,1:]
capt_train2.shape
# Out:
# (541714, 51)

# %%
capt_val = tokenizer.texts_to_sequences(annotation_list_val)
capt_val = tf.keras.preprocessing.sequence.pad_sequences(capt_val,maxlen=max_window)
capt_val
# Out:
# array([[   0,    0,    0, ...,   61, 1717,    4],
#        [   0,    0,    0, ...,    2,   25,    4],
#        [   0,    0,    0, ...,   10,  209,    4],
#        ...,
#        [   0,    0,    0, ...,    2,  254,    4],
#        [   0,    0,    0, ..., 4069,  254,    4],
#        [   0,    0,    0, ...,    2,  951,    4]], dtype=int32)

# %%
capt_val2 = capt_val[:,1:]
capt_val2.shape
# Out:
# (25021, 51)

# %%
capt_test = tokenizer.texts_to_sequences(annotation_list_test)
capt_test = tf.keras.preprocessing.sequence.pad_sequences(capt_test,maxlen=max_window)
capt_test
# Out:
# array([[   0,    0,    0, ...,    7,  635,    4],
#        [   0,    0,    0, ...,    7,  635,    4],
#        [   0,    0,    0, ...,   10, 3093,    4],
#        ...,
#        [   0,    0,    0, ...,  211,   36,    4],
#        [   0,    0,    0, ...,    7,  138,    4],
#        [   0,    0,    0, ...,    2, 3047,    4]], dtype=int32)

# %%
capt_test2 = capt_test[:,1:]
capt_test2.shape
# Out:
# (50032, 51)

# %% [markdown]
# #### Images

# %%
def load_images(ids,folder):
    images = []
    zero_padding = 12

    for idd in ids:

        img_id = str(idd)
        pic_name = "{}/COCO_{}_".format(folder,folder) + ("0"*(zero_padding - len(img_id))) + img_id + ".jpg"

        img = tf.keras.preprocessing.image.load_img(pic_name, target_size=(299, 299))
        pre_img = tf.keras.preprocessing.image.img_to_array(img)
        images.append(pre_img)

        
        
    np_images = np.array(images)
    del(images)
    pre_np_images = tf.keras.applications.resnet_v2.preprocess_input(np_images)
    del(np_images)
    
    return pre_np_images

# %% [markdown]
# # D1: Basic caption generation model
# In this section we build a basic modern caption generation model. To generate captions out of images, we embrace the encoder-decoder architecture, which consists in encoding the image in a dense short vector (with a CNN for example) and decoding the vector as a sequence of words (using some sort of RNN, e.g. LSTMs).
#
# ...
#
# ## Encoder
# We are going to use a State-Of-The-Art image classification network as our image encoder. The network in question is a CNN based residual net called ResNet.

# %%
inceptionV3 = tf.keras.applications.InceptionV3(weights="imagenet") #load inceptionV3, trained on imagenet
inceptionV3.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 149, 149, 32) 96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 149, 149, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 147, 147, 32) 9216        activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 147, 147, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 147, 147, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 64) 18432       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 64) 192         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 73, 73, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 73, 73, 80)   240         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 73, 73, 80)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 71, 71, 192)  138240      activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 71, 71, 192)  576         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 71, 71, 192)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 96)   55296       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 48)   144         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 96)   288         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 48)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 96)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 35, 35, 192)  0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 64)   76800       activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   82944       activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 35, 35, 64)   192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 64)   192         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 32)   96          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 35, 35, 64)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 64)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 32)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 96)   55296       activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 48)   144         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 96)   288         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 48)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 96)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 64)   76800       activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   82944       activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 64)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 64)   192         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 64)   192         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 64)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 64)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_12[0][0]
#                                                                  activation_14[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_18[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 96)   55296       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 48)   144         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 96)   288         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 48)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 96)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 64)   76800       activation_20[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   82944       activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 64)   192         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 64)   192         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 64)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_19[0][0]
#                                                                  activation_21[0][0]
#                                                                  activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 35, 35, 64)   192         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 35, 35, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 96)   55296       activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 96)   288         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 96)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 17, 17, 96)   82944       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 17, 17, 384)  1152        conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 17, 17, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 17, 17, 384)  0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 17, 17, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_26[0][0]
#                                                                  activation_29[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 128)  384         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 128)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  114688      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 128)  384         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  114688      activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 192)  172032      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 192)  172032      activation_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 192)  576         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 192)  576         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 192)  576         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 192)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 192)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 192)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_30[0][0]
#                                                                  activation_33[0][0]
#                                                                  activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 160)  480         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 160)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  179200      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 160)  480         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 160)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  179200      activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 192)  215040      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 192)  215040      activation_47[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 192)  576         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 192)  576         conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 192)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 192)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_40[0][0]
#                                                                  activation_43[0][0]
#                                                                  activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 160)  480         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 160)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  179200      activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 160)  480         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 160)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  179200      activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 192)  215040      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 192)  215040      activation_57[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 192)  576         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 192)  576         conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 192)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 192)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_50[0][0]
#                                                                  activation_53[0][0]
#                                                                  activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  258048      activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  258048      activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_60[0][0]
#                                                                  activation_63[0][0]
#                                                                  activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 17, 17, 192)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 8, 8, 320)    552960      activation_70[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 8, 8, 192)    331776      activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 8, 8, 320)    960         conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 8, 8, 192)    576         conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 8, 8, 320)    0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 8, 8, 192)    0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_71[0][0]
#                                                                  activation_75[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 448)    1344        conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 448)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 384)    1548288     activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 384)    1152        conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 384)    1152        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 384)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 384)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_81[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 320)    960         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 192)    576         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 320)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 768)    0           activation_82[0][0]
#                                                                  activation_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 192)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_76[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 448)    1344        conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 448)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 384)    1548288     activation_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 384)    1152        conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 384)    1152        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 384)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 384)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_86[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_90[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 320)    960         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 192)    576         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 320)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_87[0][0]
#                                                                  activation_88[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_91[0][0]
#                                                                  activation_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 192)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_85[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________

# %%
#Remove top dense layer, wrap it in a model for convenience
inception_encoder = tf.keras.Model(inputs=inceptionV3.input,outputs=inceptionV3.layers[-2].output)
inception_encoder.trainable = False #Freeze layers
inception_encoder.compile(loss=tf.keras.losses.CosineSimilarity()) # Needed for the freezing to make effect

# %%
#Loading all the images at once and running the network on the whole thing is not feasible for most systems
#This function loads and extracts the features of the images by batches, removing images that have already been processed
def load_image_features_batched(data,folder,image_batch_size = 2000,verbose=0):
    image_features = []

    for batch_i in range(0,len(data),image_batch_size):

        if verbose:
        
        start_i = batch_i
        end_i = start_i + image_batch_size

        if (end_i > len(data)):
            end_i = len(data)

        ids = [datum["id"] for datum in data[start_i:end_i]]

        some_images = load_images(ids,folder)
        pred = inception_encoder.predict(some_images)
        image_features.append(pred)

        #Delete uneeded stuff
        del(some_images)
        gc.collect()
        
    image_features_array = np.concatenate(image_features) # All but last, since last shape might be different
    return image_features_array

# %%
if not "features" in os.listdir():
    os.mkdir("features")
    
if not "image_embdd_train.npz" in os.listdir("features"):
    image_features_train = load_image_features_batched(annotations_data_train, "train2014")
    np.savez_compressed("features/image_embdd_train.npz",image_features_train)
    # %xdel image_features_train
    gc.collect()
    
if not "image_embdd_val.npz" in os.listdir("features"):
    image_features_val = load_image_features_batched(
        annotations_data_val, "val2014")
    np.savez_compressed("features/image_embdd_val.npz",image_features_val)
    # %xdel image_features_val
    gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e562dc7b84e3> in <module>
#      17 if not "image_embdd_test.npz" in os.listdir("features"):
#      18     image_features_test = load_image_features_batched(
# ---> 19         annotations_data_test, "test2014")
#      20     np.savez_compressed("features/image_embdd_test.npz",image_features_test)
#      21     get_ipython().run_line_magic('xdel', 'image_features_test')
#
# NameError: name 'annotations_data_test' is not defined

# %%
image_features_comp_train = np.load("features/image_embdd_train.npz")
image_features_comp_val = np.load("features/image_embdd_val.npz")

# %%
image_features_train = image_features_comp_train["arr_0"]
image_features_val = image_features_comp_val["arr_0"]
image_features_comp_train.close()
image_features_comp_val.close()
gc.collect()
# Out:
# 56

# %%
repeats = [len(datum["captions"]) for datum in annotations_data_train]
image_features_train_rep = np.repeat(image_features_train, repeats, axis=0)
repeats = [len(datum["captions"]) for datum in annotations_data_val]
image_features_val_rep = np.repeat(image_features_val, repeats, axis=0)
repeats = [len(datum["captions"]) for datum in annotations_data_test]
image_features_test_rep = np.repeat(image_features_test, repeats, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-2710a3ece3ea> in <module>
# ----> 1 repeats = [len(datum["captions"]) for datum in annotations_data_train]
#       2 image_features_train_rep = np.repeat(image_features_train, repeats, axis=0)
#       3 repeats = [len(datum["captions"]) for datum in annotations_data_val]
#       4 image_features_val_rep = np.repeat(image_features_val, repeats, axis=0)
#       5 repeats = [len(datum["captions"]) for datum in annotations_data_test]
#
# NameError: name 'annotations_data_train' is not defined

# %%
class LanguageModel(tf.keras.Model):
    
    def __init__(self, embedding_layer, recurrent_layer, top_layer):
        super(LanguageModel,self).__init__()
        self.embedding_layer = embedding_layer
        self.recurrent_layer = recurrent_layer
        self.top_layer = top_layer
        
    def call(self,captions):
        
        cropped_captions = captions[:,:-1]
        embeddings = self.embedding_layer(cropped_captions)
        hiddens = self.recurrent_layer(embeddings)
        output = self.top_layer(hiddens)
        
        return output

# %%
class EmbeddingLayer(tf.keras.layers.Layer):
        
        def __init__(self,max_window,embedding_count,embedding_len):
            super(EmbeddingLayer,self).__init__()
            self.embedding_layer = tf.keras.layers.Embedding(embedding_count,embedding_len,input_length=max_window,mask_zero=True)
            
        def call(self,x):
            return self.embedding_layer(x)
        
class LSTMLayer(tf.keras.layers.Layer):
        
        def __init__(self,hidden_len):
            super(LSTMLayer,self).__init__()
            self.lstm_layer = tf.keras.layers.LSTM(units=hidden_len,return_sequences=True)
            
        def call(self,x):
            return self.lstm_layer(x)
        
class MultilayerSoftmax(tf.keras.layers.Layer):
    
    def __init__(self,sizes):
            super(MultilayerSoftmax,self).__init__()
            
            self.hidden_layers = []
            self.softmax_layer = self.distributed_softmax = tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=sizes[-1],activation=tf.keras.activations.softmax))
            
            for hidden in sizes[:-1]:
                self.hidden_layers += [tf.keras.layers.TimeDistributed(tf.keras.layers.Dense(units=hidden,activation=tf.keras.activations.relu))]
            
        
    def call(self,x):
        
        for hidden_layer in self.hidden_layers:
            x = hidden_layer(x)
        
        x = self.softmax_layer(x)
        
        return x

# %%
embedding_layers = []
embedding_layers += [{"embedding_len":embdd} for embdd in [128,256,512]]

recurrent_layers = []
recurrent_layers += [{"model":"lstm" , "hidden_size": hidden} for hidden in [512, 1024, 2048, 4096]]

top_layers = []
top_layers += [{"model":"multiSoftmax" , "sizes": sizes} for sizes in 
               [[embedding_count], [embedding_count//2,embedding_count], [embedding_count//4,embedding_count//2,embedding_count]]]
top_layers
# Out:
# [{'model': 'multiSoftmax', 'sizes': [5433]},
#  {'model': 'multiSoftmax', 'sizes': [2716, 5433]},
#  {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}]

# %%
def cross_lists(listOfLists):
    
    if len(listOfLists) == 1:
        return [[lst] for lst in listOfLists[0]]
    
    crossed = cross_lists(listOfLists[1:])
    result = []
    
    for i in listOfLists[0]:
        for j in crossed:
            result.append([i]+j)
    
    return result

# %%
model_list = cross_lists([embedding_layers,recurrent_layers,top_layers])
len(model_list)
# Out:
# 36

# %%
models = [{"embedding_layer":model[0],"recurrent_layer":model[1],"top_layer":model[2]} for model in model_list]
models
# Out:
# [{'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 128},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 256},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 512},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 1024},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 2048},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [2716, 5433]}},
#  {'embedding_layer': {'embedding_len': 512},
#   'recurrent_layer': {'model': 'lstm', 'hidden_size': 4096},
#   'top_layer': {'model': 'multiSoftmax', 'sizes': [1358, 2716, 5433]}}]

# %%
def generate_model_name(model):
    
    embedding_layer = model["embedding_layer"]
    recurrent_layer = model["recurrent_layer"]
    top_layer = model["top_layer"]
    
    string = recurrent_layer["model"] + str(recurrent_layer["hidden_size"])
    string += "_embedd" + str(embedding_layer["embedding_len"])
    string += "_" + top_layer["model"] + "-".join([ str(hidd) for hidd in top_layer["sizes"]])
    
    return string

# %%
def build_embedding_layer(embedding_layer):
    return EmbeddingLayer(max_window=max_window,embedding_count=embedding_count,embedding_len=embedding_layer["embedding_len"])

def build_recurrent_layer(recurrent_layer):
    
    if (recurrent_layer["model"] == "lstm"):
        return LSTMLayer(hidden_len=recurrent_layer["hidden_size"])
    
def build_top_layer(top_layer):
    
    if (top_layer["model"] == "multiSoftmax"):
        return MultilayerSoftmax(sizes=top_layer["sizes"])

def build_model(model_desc):
    
    embedding_layer = model_desc["embedding_layer"]
    recurrent_layer = model_desc["recurrent_layer"]
    top_layer = model_desc["top_layer"]
    
    embedding = build_embedding_layer(embedding_layer)
    recurrent = build_recurrent_layer(recurrent_layer)
    top = build_top_layer(top_layer)
    
    model = LanguageModel(embedding,recurrent,top)
    model.build(input_shape=(None,max_window))
    return model

# %%
def train_model(model):

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=2)
    
    model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer = tf.keras.optimizers.Adam())
    history = model.fit(capt_train,capt_train2, validation_data=[capt_val,capt_val2],epochs=20,batch_size=64,callbacks = [early_stopping])
    
    return history

# %%
if not "models" in os.listdir():
    os.mkdir("models")
    
for model in models:
    model_name = generate_model_name(model) + ".h5"
    
    if not model_name in os.listdir("models"):
        built_model = build_model(model)
        
        print("Training model: ",model_name)
        
        train_model(built_model)
        built_model.save_weights("models/"+model_name)
        
        del(built_model)
        gc.collect()
# Out:
# Training model:  lstm512_embedd128_multiSoftmax5433.h5
# Train on 541714 samples, validate on 25021 samples
# Epoch 1/20
# 541714/541714 [==============================] - 478s 883us/sample - loss: 0.7352 - val_loss: 0.6539
# Epoch 2/20
# 541714/541714 [==============================] - 475s 877us/sample - loss: 0.6307 - val_loss: 0.6270
# Epoch 3/20
# 541714/541714 [==============================] - 475s 876us/sample - loss: 0.6070 - val_loss: 0.6172
# Epoch 4/20
# 541714/541714 [==============================] - 475s 876us/sample - loss: 0.5930 - val_loss: 0.6126
# Epoch 5/20
# 541714/541714 [==============================] - 477s 881us/sample - loss: 0.5828 - val_loss: 0.6106
# Epoch 6/20
# 541714/541714 [==============================] - 475s 877us/sample - loss: 0.5746 - val_loss: 0.6095
# Epoch 7/20
# 508032/541714 [===========================>..] - ETA: 29s - loss: 0.5675

# %% [markdown]
# Best:

# %%
for embedding_size in [128, 256, 512]:
    embedding = EmbeddingLayer(max_window=max_window,embedding_count=embedding_count,embedding_len=embedding_size)
    recurrent = LSTMLayer(hidden_len=#!!!!)
    softmax = DenseSoftmax(embedding_count=embedding_count)
    image_embedding_decoder = LanguageModel(embedding,recurrent,softmax)
    image_embedding_decoder.build(input_shape=(None,max_window))
    image_embedding_decoder.summary()
    image_embedding_decoder.fit(capt_train,capt_train2, batch_size=64, epochs=10 ,validation_data=[capt_val,capt_val2],callbacks=[early_stopping])

# %%
# Byte-pair encoding

# %%
embedding = EmbeddingLayer(max_window=max_window,embedding_count=embedding_count,embedding_len=512)
recurrent = LSTMLayer(hidden_len=512)
softmax = DenseSoftmax(embedding_count=embedding_count)

# %%
image_embedding_decoder = LanguageModel(embedding,recurrent,softmax)
image_embedding_decoder.build(input_shape=(None,max_window))
image_embedding_decoder.summary()

# %%
loss = tf.keras.losses.SparseCategoricalCrossentropy()
optimizer = tf.keras.optimizers.Adam()

image_embedding_decoder.compile(loss=loss, optimizer=optimizer)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor="val_loss",patience=3)

# %%
image_embedding_decoder.fit(capt_train,capt_train2, batch_size=64, epochs=10 ,validation_data=[capt_val,capt_val2],callbacks=[early_stopping])

# %%
image_embedding_decoder.save('model.h5')

# %%
image_embedding_decoder = tf.keras.models.load_model('model.h5')
#    custom_objects={'cropped_sparse_categorical_crossentropy': 
                    #cropped_sparse_categorical_crossentropy})

# %%
tf.keras.backend.clear_session()

# %%
#reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

# %%
capt_train[0]

# %%
sent_1 = image_embedding_decoder.predict(capt_train[0].reshape(1, -1))[0]

# %%
capt_train[0].shape

# %%
[(tokenizer.index_word[position1.argmax()], tokenizer.index_word[position2]) for position1, position2 in zip(sent_1[-9:], capt_train[0,-9:])]

# %%
for sentence in annotation_list_train[:10]:
    sentence = ' '.join(sentence.split()[:6])
    for _ in range(max_window):
        sent_tokenized = tokenizer.texts_to_sequences([sentence + " <end>" ])
        sent_padded = tf.keras.preprocessing.sequence.pad_sequences(
            sent_tokenized, maxlen=max_window)
        pred = image_embedding_decoder.predict(sent_padded)
        index = pred[0, -1].argmax()
        word = tokenizer.index_word[index]
        if word == "<end>":
            break
        sentence += " "+word
    print(sentence)

# %%
pred.shape

# %%
pred[0, -1].argmax()

# %%
reverse_word_map.get(4)

# %%
help(tf.keras.preprocessing.text.Tokenizer)

# %%
print(tokenizer.index_word)

# %% [markdown]
# ## Decoder

# %%
class Decoder(tf.keras.Model):
    
    def __init__(self, dense, embedding_layer, recurrent_layer, top_layer):
        super(Decoder, self).__init__()
        self.dense = dense
        self.embedding_layer = embedding_layer
        self.recurrent_layer = recurrent_layer
        self.top_layer = top_layer
        
    def call(self, model_input):
        img_features = model_input[0]
        captions = model_input[1]
        img_embedding = self.dense(img_features)
        img_embedding = tf.expand_dims(img_embedding, 1)
        cropped_captions = captions[:, :-1]
        embeddings = self.embedding_layer(cropped_captions)
        rnn_input = tf.concat([img_embedding, embeddings], 1)
        hiddens = self.recurrent_layer(rnn_input)
        output = self.top_layer(hiddens)
        
        return output[:, 1:]

# %%
dense = tf.keras.layers.Dense(512)

embedding = tf.keras.layers.Embedding(embedding_count,512,input_length=max_window,mask_zero=True)
#embedding = EmbeddingLayer(max_window=max_window, 
#    embedding_count=embedding_count, embedding_len=512)
recurrent = tf.keras.layers.LSTM(units=512,return_sequences=True,unroll=False)
#recurrent = LSTMLayer(hidden_len=512)
softmax = tf.keras.layers.Dense(
    embedding_count, activation=tf.keras.activations.softmax)

# %%
decoder = Decoder(dense, embedding, recurrent, softmax)
#decoder.build(input_shape=(None,max_window))
#decoder.summary()

# %%
decoder.compile(loss=loss, optimizer=optimizer, sample_weight_mode="temporal")

# %%
start_index = word_index['<start>']
train_mask = np.logical_not(np.logical_or(
        capt_train2 == 0, capt_train2 == start_index))
val_mask = np.logical_not(np.logical_or(
        capt_val2 == 0, capt_val2 == start_index))

# %%
capt_train3 = np.expand_dims(capt_train2, -1)
capt_val3 = np.expand_dims(capt_val2, -1)

# %%
decoder.fit([image_features_train_rep, capt_train], 
            capt_train3, 
            batch_size=64, 
            epochs=50,
            #callbacks=[early_stopping], 
            sample_weight=train_mask)

# %%
tokenizer.index_word[29]

# %%
# random.randrange(len(image_features_train))
for index in range(0, 200, 5):
    image = image_features_train_rep[index]
    annotation = annotation_list_train[index]
    print("Train: ", annotation)
    #print(image[:5])
    sentence = '<start> A bunch of trays that'
    for _ in range(max_window):
        sent_tokenized = tokenizer.texts_to_sequences([sentence + " <end>"])
        sent_padded = tf.keras.preprocessing.sequence.pad_sequences(
            sent_tokenized, maxlen=max_window)
        pred = decoder.predict([np.expand_dims(image, 0), sent_padded])
        index = pred[0, -1].argmax()
        denak = pred[0, :].argmax(-1)
        #print(denak)
        word = tokenizer.index_word[index]
        if word == "<end>":
            break
        sentence += " "+word
    print("Pred:  ", sentence)
